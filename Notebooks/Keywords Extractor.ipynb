# %% [markdown]
# # Keywords Extraction
# - Batch process

# %%
#core
import pandas as pd

from bs4 import BeautifulSoup
from pathlib import Path

#NLP
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from gensim.summarization import keywords

# %% [markdown]
# # Extract Keywords from IPO S-1 Filings

# %%
#load previous progress
df = pd.read_csv('2 sentiment analysis.csv', index_col='Symbol')

# %%
def extract_keywords(x):        
    #read S-1
    with open("../Data/" + x + ".htm", "r", encoding="utf-8") as f:
        html = f.read()
        soup = BeautifulSoup(html,"html5lib")
        text = soup.get_text(strip=True)

        #keywords
        words = keywords(text, ratio=0.01)

        #write keywords
        with open("../Keywords/" + x + ".txt", "w", encoding="utf-8") as f:
            #lemmatize
            lemmatized_keywords = []

            for w in word_tokenize(words):
                lemmatized_keywords.append(lemmatizer.lemmatize(w))

            lemmatized_keywords = list(set(lemmatized_keywords))

            #write
            for k in lemmatized_keywords:
                f.write('%s\n' % k)

# %%
#batch process
lemmatizer = WordNetLemmatizer()
counter = 0

for x in df.index:
    try:
        counter += 1
        print('\n( ' + str(counter) + ' / ' + str(df.shape[0]) + ' ) ' + str(x))

        #check if exists
        if Path("../Keywords/" + x + ".txt").is_file():
            print(x + ' data already exists, skipping...')
            continue

        #summarization and keywords
        extract_keywords(x)
    except Exception as e:
        print(x, e)
        #Path('../Keywords/' + x + '.txt').touch()
# Out:
# ( 1 / 696 ) AACC
# AACC data already exists, skipping...
#
# ( 2 / 696 ) AAT
# AAT data already exists, skipping...
#
# ( 3 / 696 ) ABR
# ABR
#
# ( 4 / 696 ) ABTX
# ABTX data already exists, skipping...
#
# ( 5 / 696 ) ACAD
# ACAD data already exists, skipping...
#
# ( 6 / 696 ) ACFC
# ACFC data already exists, skipping...
#
# ( 7 / 696 ) ACIA
# ACIA data already exists, skipping...
#
# ( 8 / 696 ) ACMR
# ACMR data already exists, skipping...
#
# ( 9 / 696 ) ACOR
# ACOR data already exists, skipping...
#
# ( 10 / 696 ) ACRX
# ACRX data already exists, skipping...
#
# ( 11 / 696 ) ACUS
# ACUS data already exists, skipping...
#
# ( 12 / 696 ) ADMS
# ADMS data already exists, skipping...
#
# ( 13 / 696 ) ADOM
# ADOM data already exists, skipping...
#
# ( 14 / 696 ) ADRO
# ADRO data already exists, skipping...
#
# ( 15 / 696 ) ADSW
# ADSW data already exists, skipping...
#
# ( 16 / 696 ) ADT
# ADT data already exists, skipping...
#
# ( 17 / 696 ) ADUS
# ADUS data already exists, skipping...
#
# ( 18 / 696 ) AEL
# AEL data already exists, skipping...
#
# ( 19 / 696 ) AERI
# AERI data already exists, skipping...
#
# ( 20 / 696 ) AFFY
# AFFY data already exists, skipping...
#
# ( 21 / 696 ) AFH
# AFH data already exists, skipping...
#
# ( 22 / 696 ) AIMC
# AIMC data already exists, skipping...
#
# ( 23 / 696 ) AIMT
# AIMT data already exists, skipping...
#
# ( 24 / 696 ) AIZ
# AIZ
#
# ( 25 / 696 ) AJX
# AJX data already exists, skipping...
#
# ( 26 / 696 ) AKAO
# AKAO data already exists, skipping...
#
# ( 27 / 696 ) AKBA
# AKBA data already exists, skipping...
#
# ( 28 / 696 ) AKER
# AKER data already exists, skipping...
#
# ( 29 / 696 ) AL
# AL data already exists, skipping...
#
# ( 30 / 696 ) ALDR
# ALDR data already exists, skipping...
#
# ( 31 / 696 ) ALDX
# ALDX data already exists, skipping...
#
# ( 32 / 696 ) ALGT
# ALGT data already exists, skipping...
#
# ( 33 / 696 ) ALRM
# ALRM data already exists, skipping...
#
# ( 34 / 696 ) ALRN
# ALRN data already exists, skipping...
#
# ( 35 / 696 ) ALSN
# ALSN data already exists, skipping...
#
# ( 36 / 696 ) AM
# AM data already exists, skipping...
#
# ( 37 / 696 ) AMBA
# AMBA data already exists, skipping...
#
# ( 38 / 696 ) AMGP
# AMGP data already exists, skipping...
#
# ( 39 / 696 ) ANAB
# ANAB data already exists, skipping...
#
# ( 40 / 696 ) ANET
# ANET data already exists, skipping...
#
# ( 41 / 696 ) ANGI
# ANGI data already exists, skipping...
#
# ( 42 / 696 ) ANTH
# ANTH data already exists, skipping...
#
# ( 43 / 696 ) APAM
# APAM data already exists, skipping...
#
# ( 44 / 696 ) APEI
# APEI data already exists, skipping...
#
# ( 45 / 696 ) APKT
# APKT data already exists, skipping...
#
# ( 46 / 696 ) APO
