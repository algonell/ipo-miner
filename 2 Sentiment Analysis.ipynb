# %% [markdown]
# # Sentiment Analysis
# - First attempt to add raw IPO filings data
# - The art of Feature Enginnering
# - Add Sentimnet Analysis features
#  - Tokenize sentences
#  - Use positive and negative sentences at 95th percentile means

# %%
#core
# %matplotlib inline
import matplotlib.pyplot as plt

import pandas as pd

import glob
import nasdaq
import ml
from bs4 import BeautifulSoup
from pathlib import Path

#NLP
from nltk.tokenize import sent_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# # Load Baseline

# %%
#load and sort by date priced
df = pd.read_csv('1 baseline.csv', index_col='Symbol')

# %% [markdown]
# # Integrating IPO Raw Data

# %%
def get_sentiment_df(text):
    '''returns Sentiment Analysis'''
    sid = SentimentIntensityAnalyzer()
    ps_list = []
    sentences = sent_tokenize(text)
    
    for sentence in sentences:
        ps = sid.polarity_scores(sentence)
        ps['sent'] = sentence
        ps_list.append(ps)
    
    df = pd.DataFrame(ps_list)

    return df

# %%
def add_sentiment_features(df_sentiment, symbol):
    '''Adds Sentiment Snalysis features, returns DataFrame'''
    
    #filter frames
    df_tmp = pd.DataFrame()
    pos = df_sentiment[df_sentiment['pos'] > df_sentiment['pos'].quantile(0.95)]
    neg = df_sentiment[df_sentiment['neg'] > df_sentiment['neg'].quantile(0.95)]

    #sentences features
    df_tmp.at[symbol, 'Mean Sent Len'] = df_sentiment['sent'].str.len().mean()
    df_tmp.at[symbol, 'Sent Count'] = df_sentiment.shape[0]

    #pos sentiment
    df_tmp.at[symbol, 'Pos Mean Sent Len'] = pos['sent'].str.len().mean()
    df_tmp.at[symbol, 'Pos Sent Count'] = pos.shape[0]
    pos = pos[['compound', 'neg', 'neu', 'pos']]
    df_tmp = pd.concat([pd.DataFrame(pos.mean(), columns=[symbol]).T.add_prefix('Pos Sent Signal '), df_tmp], axis=1)

    #pos sentiment
    df_tmp.at[symbol, 'Neg Mean Sent Len'] = neg['sent'].str.len().mean()
    df_tmp.at[symbol, 'Neg Sent Count'] = neg.shape[0]
    neg = neg[['compound', 'neg', 'neu', 'pos']]
    df_tmp = pd.concat([pd.DataFrame(neg.mean(), columns=[symbol]).T.add_prefix('Neg Sent Signal '), df_tmp], axis=1)
    
    return df_tmp

# %%
#add sentiment features
df_sentiment_features = pd.DataFrame()
counter = 0    

for x in df.index:
    try:
        counter += 1
        print('\n( ' + str(counter) + ' / ' + str(df.shape[0]) + ' ) ' + x)

        #check if raw data is available
        file_name = "./Data/" + x + ".htm"
        if Path(file_name).is_file():
            #load raw IPO filing
            with open(file_name, "r", encoding="utf-8") as file:
                html = file.read()
                soup = BeautifulSoup(html,"html5lib")
                text = soup.get_text(strip=True)

                #get sentiment
                df_sentiment = get_sentiment_df(text)
                df_sentiment_features = pd.concat([df_sentiment_features, add_sentiment_features(df_sentiment, x)], axis=0)
        else:
            print('no S-1 for ', x)
    except Exception as e:
        print(x, e)
        
#combine original data with standardized sentiment features
df1 = pd.concat([ml.standardize(df_sentiment_features), df], axis=1).dropna()
# Out:
# ( 1 / 951 ) WQNI
# no S-1 for  WQNI
#
# ( 2 / 951 ) BBGI
#
# ( 3 / 951 ) UTSI
# no S-1 for  UTSI
#
# ( 4 / 951 ) SLAB
# no S-1 for  SLAB
#
# ( 5 / 951 ) ALTH
# no S-1 for  ALTH
#
# ( 6 / 951 ) WBSN
# no S-1 for  WBSN
#
# ( 7 / 951 ) MET
# no S-1 for  MET
#
# ( 8 / 951 ) LPSN
# no S-1 for  LPSN
#
# ( 9 / 951 ) HSTM
# no S-1 for  HSTM
#
# ( 10 / 951 ) PXLW
# no S-1 for  PXLW
#
# ( 11 / 951 ) CYH
# no S-1 for  CYH
#
# ( 12 / 951 ) CRL
# no S-1 for  CRL
#
# ( 13 / 951 ) QBAK
# no S-1 for  QBAK
#
# ( 14 / 951 ) ACLS
# no S-1 for  ACLS
#
# ( 15 / 951 ) SOHU
# no S-1 for  SOHU
#
# ( 16 / 951 ) SRTI
# no S-1 for  SRTI
#
# ( 17 / 951 ) PTIE
# no S-1 for  PTIE
#
# ( 18 / 951 ) SPRT
# no S-1 for  SPRT
#
# ( 19 / 951 ) SMTX
#
# ( 20 / 951 ) ARNA
# no S-1 for  ARNA
#
# ( 21 / 951 ) CAMT
# no S-1 for  CAMT
#
# ( 22 / 951 ) ILMN
# no S-1 for  ILMN
#
# ( 23 / 951 ) EVC
#
# ( 24 / 951 ) DGEN
# no S-1 for  DGEN
#
# ( 25 / 951 ) ERMS
# no S-1 for  ERMS
#
# ( 26 / 951 ) LTRX
# no S-1 for  LTRX
#
# ( 27 / 951 ) MDCO
# no S-1 for  MDCO
#
# ( 28 / 951 ) EQIX
# no S-1 for  EQIX
#
# ( 29 / 951 ) DRRX
# no S-1 for  DRRX
#
# ( 30 / 951 ) MON
#
# ( 31 / 951 ) WIT
# no S-1 for  WIT
#
# ( 32 / 951 ) RIGL
# no S-1 for  RIGL
#
# ( 33 / 951 ) GRMN
# no S-1 for  GRMN
#
# ( 34 / 951 ) RECN
# no S-1 for  RECN
#
# ( 35 / 951 ) PEET
# no S-1 for  PEET
#
# ( 36 / 951 ) OIS
#
# ( 37 / 951 ) ACN
# no S-1 for  ACN
#
# ( 38 / 951 ) MDTH
#
# ( 39 / 951 ) PFG
# no S-1 for  PFG
#
# ( 40 / 951 ) WTW
#
# ( 41 / 951 ) PRU
# no S-1 for  PRU
#
# ( 42 / 951 ) SYNA
#
# ( 43 / 951 ) MANT
#
# ( 44 / 951 ) GME
# no S-1 for  GME
#
# ( 45 / 951 ) JBLU
#
# ( 46 / 951 ) VRNT
#
# ( 47 / 951 ) CPSI
#
# ( 48 / 951 ) LQMT
#
# ( 49 / 951 ) NFLX
#
# ( 50 / 951 ) OSTK
#
# ( 51 / 951 ) PACR
# no S-1 for  PACR
#
# ( 52 / 951 ) BGFV
#
# ( 53 / 951 ) DKS
#
# ( 54 / 951 ) NGS
#
# ( 55 / 951 ) PRAA
# no S-1 for  PRAA
#
# ( 56 / 951 ) OTIV
# no S-1 for  OTIV
#
# ( 57 / 951 ) CME
#
# ( 58 / 951 ) PFS
#
# ( 59 / 951 ) IPCC
# no S-1 for  IPCC
#
# ( 60 / 951 ) FORM
#
# ( 61 / 951 ) MOH
#
# ( 62 / 951 ) CHT
# no S-1 for  CHT
#
# ( 63 / 951 ) NTGR
#
# ( 64 / 951 ) CSE
#
# ( 65 / 951 ) NFP
#
# ( 66 / 951 ) ACUS
#
# ( 67 / 951 ) CHLE
# no S-1 for  CHLE
#
# ( 68 / 951 ) MRLN
#
# ( 69 / 951 ) WLL
#
# ( 70 / 951 ) CONN
#
# ( 71 / 951 ) SNX
#
# ( 72 / 951 ) AEL
#
# ( 73 / 951 ) CTRP
# no S-1 for  CTRP
#
# ( 74 / 951 ) CMP
#
# ( 75 / 951 ) TPX
#
# ( 76 / 951 ) GTXI
#
# ( 77 / 951 ) AACC
#
# ( 78 / 951 ) AIZ
#
# ( 79 / 951 ) DVAX
#
# ( 80 / 951 ) TNS
# no S-1 for  TNS
#
# ( 81 / 951 ) LSE
#
# ( 82 / 951 ) CUTR
#
# ( 83 / 951 ) MCHX
# no S-1 for  MCHX
#
# ( 84 / 951 ) ABR
#
# ( 85 / 951 ) INTX
#
# ( 86 / 951 ) GHL
#
# ( 87 / 951 ) ACAD
#
# ( 88 / 951 ) CRTX
#
# ( 89 / 951 ) DRAD
#
# ( 90 / 951 ) SNMX
#
# ( 91 / 951 ) MNTA
#
# ( 92 / 951 ) CRM
#
# ( 93 / 951 ) GOL
# no S-1 for  GOL
#
# ( 94 / 951 ) WCG
#
# ( 95 / 951 ) HEP
#
# ( 96 / 951 ) DPZ
# no S-1 for  DPZ
#
# ( 97 / 951 ) QCCO
# no S-1 for  QCCO
#
# ( 98 / 951 ) LPL
# no S-1 for  LPL
#
# ( 99 / 951 ) MNKD
#
# ( 100 / 951 ) VLTR
#
# ( 101 / 951 ) GOOG
#
# ( 102 / 951 ) STON
#
# ( 103 / 951 ) BECN
#
# ( 104 / 951 ) JOBS
# no S-1 for  JOBS
#
# ( 105 / 951 ) SIFI
# no S-1 for  SIFI
#
# ( 106 / 951 ) ACFC
#
# ( 107 / 951 ) TXRH
#
# ( 108 / 951 ) NWY
#
# ( 109 / 951 ) TPGI
#
# ( 110 / 951 ) HURN
#
# ( 111 / 951 ) BBW
#
# ( 112 / 951 ) MKTX
#
# ( 113 / 951 ) ORA
# no S-1 for  ORA
#
# ( 114 / 951 ) MPWR
# no S-1 for  MPWR
#
# ( 115 / 951 ) CHCI
#
# ( 116 / 951 ) KNL
#
# ( 117 / 951 ) LVS
#
# ( 118 / 951 ) NCTY
# no S-1 for  NCTY
#
# ( 119 / 951 ) OTT
#
# ( 120 / 951 ) MIC
#
# ( 121 / 951 ) WTI
#
# ( 122 / 951 ) DRYS
# no S-1 for  DRYS
#
# ( 123 / 951 ) GRVY
# no S-1 for  GRVY
#
# ( 124 / 951 ) DLB
#
# ( 125 / 951 ) KRNY
#
# ( 126 / 951 ) PBIP
#
# ( 127 / 951 ) RAIL
#
# ( 128 / 951 ) DXCM
#
# ( 129 / 951 ) PAY
#
# ( 130 / 951 ) MORN
#
# ( 131 / 951 ) LAZ
# no S-1 for  LAZ
#
# ( 132 / 951 ) TGP
# no S-1 for  TGP
#
# ( 133 / 951 ) ZUMZ
#
# ( 134 / 951 ) CNTF
# no S-1 for  CNTF
#
# ( 135 / 951 ) CTRN
#
# ( 136 / 951 ) TLP
#
# ( 137 / 951 ) DRH
#
# ( 138 / 951 ) DSW
# no S-1 for  DSW
#
# ( 139 / 951 ) SIMO
# no S-1 for  SIMO
#
# ( 140 / 951 ) MPW
#
# ( 141 / 951 ) FMCN
# no S-1 for  FMCN
#
# ( 142 / 951 ) TIS
#
# ( 143 / 951 ) CNSL
#
# ( 144 / 951 ) BIDU
# no S-1 for  BIDU
#
# ( 145 / 951 ) RUTH
#
# ( 146 / 951 ) ROLL
#
# ( 147 / 951 ) KONA
#
# ( 148 / 951 ) WPZ
#
# ( 149 / 951 ) SNSS
#
# ( 150 / 951 ) CBOU
#
# ( 151 / 951 ) GLP
# no S-1 for  GLP
#
# ( 152 / 951 ) GASS
# no S-1 for  GASS
#
# ( 153 / 951 ) NXTM
#
# ( 154 / 951 ) SPWR
#
# ( 155 / 951 ) BKD
#
# ( 156 / 951 ) BAS
#
# ( 157 / 951 ) CAPB
#
# ( 158 / 951 ) SOMX
#
# ( 159 / 951 ) CMG
#
# ( 160 / 951 ) HEES
#
# ( 161 / 951 ) KOP
#
# ( 162 / 951 ) TX
# no S-1 for  TX
#
# ( 163 / 951 ) ETE
#
# ( 164 / 951 ) CROX
#
# ( 165 / 951 ) ACOR
#
# ( 166 / 951 ) LOV
#
# ( 167 / 951 ) TDG
#
# ( 168 / 951 ) ZZ
#
# ( 169 / 951 ) VNDA
#
# ( 170 / 951 ) DK
#
# ( 171 / 951 ) BMTI
#
# ( 172 / 951 ) MA
#
# ( 173 / 951 ) CLUB
#
# ( 174 / 951 ) HWCC
#
# ( 175 / 951 ) SNCR
#
# ( 176 / 951 ) HOMB
# no S-1 for  HOMB
#
# ( 177 / 951 ) PGTI
#
# ( 178 / 951 ) ROMA
#
# ( 179 / 951 ) GSG
#
# ( 180 / 951 ) GTLS
#
# ( 181 / 951 ) WNS
# no S-1 for  WNS
#
# ( 182 / 951 ) GMET
#
# ( 183 / 951 ) SDEV
#
# ( 184 / 951 ) GORO
# no S-1 for  GORO
#
# ( 185 / 951 ) CVLT
#
# ( 186 / 951 ) PBIB
#
# ( 187 / 951 ) EVEP
#
# ( 188 / 951 ) OFSI
#
# ( 189 / 951 ) WU
#
# ( 190 / 951 ) APKT
#
# ( 191 / 951 ) LMAT
#
# ( 192 / 951 ) SONA
#
# ( 193 / 951 ) OC
#
# ( 194 / 951 ) CPRX
#
# ( 195 / 951 ) CSIQ
# no S-1 for  CSIQ
#
# ( 196 / 951 ) EBS
#
# ( 197 / 951 ) ALLT
# no S-1 for  ALLT
#
# ( 198 / 951 ) HTZ
#
# ( 199 / 951 ) FSLR
#
# ( 200 / 951 ) AER
# no S-1 for  AER
#
# ( 201 / 951 ) WLDN
#
# ( 202 / 951 ) NOA
# no S-1 for  NOA
#
# ( 203 / 951 ) OMAB
# no S-1 for  OMAB
#
# ( 204 / 951 ) ALGT
#
# ( 205 / 951 ) ANW
# no S-1 for  ANW
#
# ( 206 / 951 ) OMPI
#
# ( 207 / 951 ) TAST
#
# ( 208 / 951 ) AIMC
#
# ( 209 / 951 ) AFFY
#
# ( 210 / 951 ) FFHL
# no S-1 for  FFHL
#
# ( 211 / 951 ) DBA
#
# ( 212 / 951 ) AVAV
#
# ( 213 / 951 ) ORIT
#
# ( 214 / 951 ) JASO
# no S-1 for  JASO
#
# ( 215 / 951 ) SSRX
# no S-1 for  SSRX
#
# ( 216 / 951 ) MLNX
#
# ( 217 / 951 ) NCMI
#
# ( 218 / 951 ) OPTR
#
# ( 219 / 951 ) CLWR
#
# ( 220 / 951 ) GFA
# no S-1 for  GFA
#
# ( 221 / 951 ) CQP
#
# ( 222 / 951 ) GLUU
#
# ( 223 / 951 ) SMCI
#
# ( 224 / 951 ) UNG
#
# ( 225 / 951 ) TFSL
#
# ( 226 / 951 ) CNK
#
# ( 227 / 951 ) OPTT
#
# ( 228 / 951 ) CAVM
#
# ( 229 / 951 ) ATV
# no S-1 for  ATV
#
# ( 230 / 951 ) PBSV
# no S-1 for  PBSV
#
# ( 231 / 951 ) ACM
# no S-1 for  ACM
#
# ( 232 / 951 ) JMP
#
# ( 233 / 951 ) PODD
#
# ( 234 / 951 ) TTGT
# no S-1 for  TTGT
#
# ( 235 / 951 ) GLRE
# no S-1 for  GLRE
#
# ( 236 / 951 ) CLNE
#
# ( 237 / 951 ) FOLD
#
# ( 238 / 951 ) INFN
# no S-1 for  INFN
#
# ( 239 / 951 ) LLNW
#
# ( 240 / 951 ) AUTH
#
# ( 241 / 951 ) SPRD
# no S-1 for  SPRD
#
# ( 242 / 951 ) BNCL
#
# ( 243 / 951 ) REXX
#
# ( 244 / 951 ) LULU
#
# ( 245 / 951 ) CXO
# no S-1 for  CXO
#
# ( 246 / 951 ) VRTU
#
# ( 247 / 951 ) MASI
#
# ( 248 / 951 ) MELI
#
# ( 249 / 951 ) DUF
#
# ( 250 / 951 ) BFED
#
# ( 251 / 951 ) MAPP
#
# ( 252 / 951 ) TGH
# no S-1 for  TGH
#
# ( 253 / 951 ) CVI
#
# ( 254 / 951 ) PZN
#
# ( 255 / 951 ) NBY
#
# ( 256 / 951 ) ARYX
#
# ( 257 / 951 ) NFBK
#
# ( 258 / 951 ) APEI
#
# ( 259 / 951 ) ENSG
#
# ( 260 / 951 ) NMM
# no S-1 for  NMM
#
# ( 261 / 951 ) OZM
#
# ( 262 / 951 ) GTS
#
# ( 263 / 951 ) VIT
# no S-1 for  VIT
#
# ( 264 / 951 ) LRN
# no S-1 for  LRN
#
# ( 265 / 951 ) TNK
# no S-1 for  TNK
#
# ( 266 / 951 ) ACLZ
# no S-1 for  ACLZ
#
# ( 267 / 951 ) EBSB
#
# ( 268 / 951 ) GCC
#
# ( 269 / 951 ) SOL
# no S-1 for  SOL
#
# ( 270 / 951 ) HCCI
#
# ( 271 / 951 ) BEAT
#
# ( 272 / 951 ) V
# no S-1 for  V
#
# ( 273 / 951 ) MHLD
#
# ( 274 / 951 ) CFX
# no S-1 for  CFX
#
# ( 275 / 951 ) WES
#
# ( 276 / 951 ) SINO
#
# ( 277 / 951 ) ERII
#
# ( 278 / 951 ) DL
# no S-1 for  DL
#
# ( 279 / 951 ) LOPE
#
# ( 280 / 951 ) CYOU
# no S-1 for  CYOU
#
# ( 281 / 951 ) MDSO
#
# ( 282 / 951 ) LOGM
#
# ( 283 / 951 ) TBNK
#
# ( 284 / 951 ) GSM
#
# ( 285 / 951 ) PMT
#
# ( 286 / 951 ) RCON
#
# ( 287 / 951 ) STWD
#
# ( 288 / 951 ) LIWA
#
# ( 289 / 951 ) SGOL
#
# ( 290 / 951 ) DNO
#
# ( 291 / 951 ) ECHO
#
# ( 292 / 951 ) BSBR
# no S-1 for  BSBR
#
# ( 293 / 951 ) VRSK
#
# ( 294 / 951 ) MG
#
# ( 295 / 951 ) OMER
#
# ( 296 / 951 ) ZSTN
#
# ( 297 / 951 ) VSI
#
# ( 298 / 951 ) ADUS
#
# ( 299 / 951 ) STRI
# no S-1 for  STRI
#
# ( 300 / 951 ) DG
#
# ( 301 / 951 ) RUE
#
# ( 302 / 951 ) PEB
#
# ( 303 / 951 ) NKBP
# no S-1 for  NKBP
#
# ( 304 / 951 ) CCM
# no S-1 for  CCM
#
# ( 305 / 951 ) PDM
#
# ( 306 / 951 ) ANTH
#
# ( 307 / 951 ) ST
# no S-1 for  ST
#
# ( 308 / 951 ) AVEO
#
# ( 309 / 951 ) FNGN
#
# ( 310 / 951 ) CALX
#
# ( 311 / 951 ) MXL
#
# ( 312 / 951 ) HTHT
# no S-1 for  HTHT
#
# ( 313 / 951 ) SSNC
#
# ( 314 / 951 ) STNG
# no S-1 for  STNG
#
# ( 315 / 951 ) PRI
#
# ( 316 / 951 ) MITL
# no S-1 for  MITL
#
# ( 317 / 951 ) SPSC
#
# ( 318 / 951 ) AOSL
# no S-1 for  AOSL
#
# ( 319 / 951 ) TNAV
#
# ( 320 / 951 ) JKS
# no S-1 for  JKS
#
# ( 321 / 951 ) GNMK
#
# ( 322 / 951 ) BNO
#
# ( 323 / 951 ) CORN
#
# ( 324 / 951 ) CBOE
#
# ( 325 / 951 ) OAS
#
# ( 326 / 951 ) HPP
#
# ( 327 / 951 ) FN
#
# ( 328 / 951 ) ECT
#
# ( 329 / 951 ) GDOT
#
# ( 330 / 951 ) NXPI
# no S-1 for  NXPI
#
# ( 331 / 951 ) USCI
#
# ( 332 / 951 ) MMYT
# no S-1 for  MMYT
#
# ( 333 / 951 ) ELMD
# ( 334 / 951 ) WSR
# no S-1 for  WSR
#
# ( 335 / 951 ) COR
#
# ( 336 / 951 ) CCIH
# no S-1 for  CCIH
#
# ( 337 / 951 ) DQ
# no S-1 for  DQ
#
# ( 338 / 951 ) STND
#
# ( 339 / 951 ) TOWR
#
# ( 340 / 951 ) BBRG
#
# ( 341 / 951 ) VRA
#
# ( 342 / 951 ) GLTR
#
# ( 343 / 951 ) PACB
#
# ( 344 / 951 ) PSLV
# no S-1 for  PSLV
#
# ( 345 / 951 ) SODA
# no S-1 for  SODA
#
# ( 346 / 951 ) CMRE
# no S-1 for  CMRE
#
# ( 347 / 951 ) PRMW
#
# ( 348 / 951 ) NOAH
# no S-1 for  NOAH
#
# ( 349 / 951 ) GM
#
# ( 350 / 951 ) LPLA
#
# ( 351 / 951 ) WITE
#
# ( 352 / 951 ) TRGP
#
# ( 353 / 951 ) GCAP
#
# ( 354 / 951 ) RNET
#
# ( 355 / 951 ) WD
#
# ( 356 / 951 ) OSN
# no S-1 for  OSN
#
# ( 357 / 951 ) AAT
#
# ( 358 / 951 ) BCDS
# no S-1 for  BCDS
#
# ( 359 / 951 ) BKU
#
# ( 360 / 951 ) INXN
# no S-1 for  INXN
#
# ( 361 / 951 ) NAGS
#
# ( 362 / 951 ) NPTN
# no S-1 for  NPTN
#
# ( 363 / 951 ) PCRX
#
# ( 364 / 951 ) BGMD
#
# ( 365 / 951 ) ECYT
#
# ( 366 / 951 ) GEVO
#
# ( 367 / 951 ) INN
#
# ( 368 / 951 ) ACRX
#
# ( 369 / 951 ) CRUD
#
# ( 370 / 951 ) HCA
# no S-1 for  HCA
#
# ( 371 / 951 ) MX
#
# ( 372 / 951 ) CSOD
#
# ( 373 / 951 ) SREV
#
# ( 374 / 951 ) APO
#
# ( 375 / 951 ) GNC
#
# ( 376 / 951 ) SDT
#
# ( 377 / 951 ) GMLP
# no S-1 for  GMLP
#
# ( 378 / 951 ) ZIP
#
# ( 379 / 951 ) ELLI
#
# ( 380 / 951 ) AL
#
# ( 381 / 951 ) MKTG
#
# ( 382 / 951 ) VNET
# no S-1 for  VNET
#
# ( 383 / 951 ) RENN
# no S-1 for  RENN
#
# ( 384 / 951 ) WIFI
#
# ( 385 / 951 ) RLJ
#
# ( 386 / 951 ) KOS
#
# ( 387 / 951 ) SAVE
#
# ( 388 / 951 ) P
#
# ( 389 / 951 ) SXC
#
# ( 390 / 951 ) FRAN
#
# ( 391 / 951 ) DNKN
#
# ( 392 / 951 ) CHEF
#
# ( 393 / 951 ) CARB
#
# ( 394 / 951 ) PER
#
# ( 395 / 951 ) TUDO
# no S-1 for  TUDO
#
# ( 396 / 951 ) CANE
#
# ( 397 / 951 ) SOYB
#
# ( 398 / 951 ) WEAT
#
# ( 399 / 951 ) NDRO
#
# ( 400 / 951 ) GRPN
#
# ( 401 / 951 ) CLVS
#
# ( 402 / 951 ) ANGI
#
# ( 403 / 951 ) DLPH
#
# ( 404 / 951 ) IMI
#
# ( 405 / 951 ) BCEI
#
# ( 406 / 951 ) KORS
# no S-1 for  KORS
#
# ( 407 / 951 ) LPI
#
# ( 408 / 951 ) MCEP
#
# ( 409 / 951 ) ZNGA
#
# ( 410 / 951 ) VSTM
#
# ( 411 / 951 ) SLCA
#
# ( 412 / 951 ) CZR
# no S-1 for  CZR
#
# ( 413 / 951 ) HMST
#
# ( 414 / 951 ) BCOV
#
# ( 415 / 951 ) PRLB
#
# ( 416 / 951 ) NSM
#
# ( 417 / 951 ) ALSN
#
# ( 418 / 951 ) CSTE
# no S-1 for  CSTE
#
# ( 419 / 951 ) RM
#
# ( 420 / 951 ) TAGS
#
# ( 421 / 951 ) VCRA
#
# ( 422 / 951 ) MACK
#
# ( 423 / 951 ) PRSS
#
# ( 424 / 951 ) RXN
# no S-1 for  RXN
#
# ( 425 / 951 ) ENPH
#
# ( 426 / 951 ) GLOG
# no S-1 for  GLOG
#
# ( 427 / 951 ) FET
#
# ( 428 / 951 ) MRC
#
# ( 429 / 951 ) OAK
#
# ( 430 / 951 ) SDR
#
# ( 431 / 951 ) SPLK
#
# ( 432 / 951 ) MPO
#
# ( 433 / 951 ) PFPT
#
# ( 434 / 951 ) SUPN
#
# ( 435 / 951 ) TLYS
#
# ( 436 / 951 ) EVAC
# no S-1 for  EVAC
#
# ( 437 / 951 ) EQM
#
# ( 438 / 951 ) NOW
#
# ( 439 / 951 ) FSBW
#
# ( 440 / 951 ) KYAK
#
# ( 441 / 951 ) PANW
#
# ( 442 / 951 ) CHUY
#
# ( 443 / 951 ) NGVC
#
# ( 444 / 951 ) GMED
#
# ( 445 / 951 ) BLMN
#
# ( 446 / 951 ) PFMT
#
# ( 447 / 951 ) MANU
# no S-1 for  MANU
#
# ( 448 / 951 ) HCLP
#
# ( 449 / 951 ) NBHC
#
# ( 450 / 951 ) BSMX
# no S-1 for  BSMX
#
# ( 451 / 951 ) QLYS
#
# ( 452 / 951 ) BERY
#
# ( 453 / 951 ) AMBA
#
# ( 454 / 951 ) ICPT
#
# ( 455 / 951 ) RLGY
#
# ( 456 / 951 ) SSTK
#
# ( 457 / 951 ) WDAY
#
# ( 458 / 951 ) SDLP
# no S-1 for  SDLP
#
# ( 459 / 951 ) MPLX
# no S-1 for  MPLX
#
# ( 460 / 951 ) RH
# no S-1 for  RH
#
# ( 461 / 951 ) DKL
#
# ( 462 / 951 ) WHLR
#
# ( 463 / 951 ) PBF
#
# ( 464 / 951 ) SPPP
# no S-1 for  SPPP
#
# ( 465 / 951 ) USAC
#
# ( 466 / 951 ) CVRR
#
# ( 467 / 951 ) NCLH
#
# ( 468 / 951 ) SXCP
#
# ( 469 / 951 ) BFAM
#
# ( 470 / 951 ) LAND
#
# ( 471 / 951 ) STML
#
# ( 472 / 951 ) TPH
#
# ( 473 / 951 ) ZTS
#
# ( 474 / 951 ) BCC
#
# ( 475 / 951 ) AFH
#
# ( 476 / 951 ) ORC
#
# ( 477 / 951 ) APAM
#
# ( 478 / 951 ) MODN
#
# ( 479 / 951 ) TTPH
#
# ( 480 / 951 ) ENTA
#
# ( 481 / 951 ) MRIN
#
# ( 482 / 951 ) PF
#
# ( 483 / 951 ) CGIX
#
# ( 484 / 951 ) KNOP
# no S-1 for  KNOP
#
# ( 485 / 951 ) TMHC
#
# ( 486 / 951 ) CMRX
#
# ( 487 / 951 ) EVTC
#
# ( 488 / 951 ) SEAS
#
# ( 489 / 951 ) EARN
#
# ( 490 / 951 ) QIWI
# no S-1 for  QIWI
#
# ( 491 / 951 ) EMES
# no S-1 for  EMES
#
# ( 492 / 951 ) PFSI
#
# ( 493 / 951 ) TEP
#
# ( 494 / 951 ) DATA
#
# ( 495 / 951 ) PTLA
#
# ( 496 / 951 ) BRSS
#
# ( 497 / 951 ) CSTM
# no S-1 for  CSTM
#
# ( 498 / 951 ) ECOM
#
# ( 499 / 951 ) LITB
# no S-1 for  LITB
#
# ( 500 / 951 ) PTCT
#
# ( 501 / 951 ) GOGO
#
# ( 502 / 951 ) LXFT
# no S-1 for  LXFT
#
# ( 503 / 951 ) NSTG
#
# ( 504 / 951 ) PETX
#
# ( 505 / 951 ) SAMG
#
# ( 506 / 951 ) HDS
#
# ( 507 / 951 ) NDLS
#
# ( 508 / 951 ) NYLD
#
# ( 509 / 951 ) OMED
#
# ( 510 / 951 ) DOC
# no S-1 for  DOC
#
# ( 511 / 951 ) REXR
#
# ( 512 / 951 ) PSXP
#
# ( 513 / 951 ) GRAM
# no S-1 for  GRAM
#
# ( 514 / 951 ) HTBX
# HTBX 'pos'
#
# ( 515 / 951 ) JONE
#
# ( 516 / 951 ) CNAT
#
# ( 517 / 951 ) ONTX
#
# ( 518 / 951 ) MBII
#
# ( 519 / 951 ) CTRL
# no S-1 for  CTRL
#
# ( 520 / 951 ) FOXF
#
# ( 521 / 951 ) MIXT
# no S-1 for  MIXT
#
# ( 522 / 951 ) CCCR
#
# ( 523 / 951 ) EVHC
#
# ( 524 / 951 ) TPRE
# no S-1 for  TPRE
#
# ( 525 / 951 ) BNFT
#
# ( 526 / 951 ) FPRX
#
# ( 527 / 951 ) VLRS
# no S-1 for  VLRS
#
# ( 528 / 951 ) FEYE
#
# ( 529 / 951 ) FMI
#
# ( 530 / 951 ) OPHT
#
# ( 531 / 951 ) PINC
#
# ( 532 / 951 ) PEGI
#
# ( 533 / 951 ) RNG
#
# ( 534 / 951 ) RMAX
#
# ( 535 / 951 ) ESRT
#
# ( 536 / 951 ) PBPB
#
# ( 537 / 951 ) CHMI
#
# ( 538 / 951 ) OCIP
# no S-1 for  OCIP
#
# ( 539 / 951 ) QTS
#
# ( 540 / 951 ) MGNX
#
# ( 541 / 951 ) PAGP
#
# ( 542 / 951 ) VEEV
#
# ( 543 / 951 ) VJET
# no S-1 for  VJET
#
# ( 544 / 951 ) AERI
#
# ( 545 / 951 ) COMM
#
# ( 546 / 951 ) SRLP
#
# ( 547 / 951 ) BRX
#
# ( 548 / 951 ) CRTO
# no S-1 for  CRTO
#
# ( 549 / 951 ) VCYT
#
# ( 550 / 951 ) WUBA
# no S-1 for  WUBA
#
# ( 551 / 951 ) MMI
#
# ( 552 / 951 ) ESNT
#
# ( 553 / 951 ) TCS
#
# ( 554 / 951 ) BCRH
#
# ( 555 / 951 ) KPTI
#
# ( 556 / 951 ) WIX
# no S-1 for  WIX
#
# ( 557 / 951 ) TWTR
#
# ( 558 / 951 ) CHGG
#
# ( 559 / 951 ) DLNG
# no S-1 for  DLNG
#
# ( 560 / 951 ) EROS
# no S-1 for  EROS
#
# ( 561 / 951 ) STAY
#
# ( 562 / 951 ) HMHC
#
# ( 563 / 951 ) OXFD
#
# ( 564 / 951 ) VNCE
#
# ( 565 / 951 ) WBAI
# no S-1 for  WBAI
#
# ( 566 / 951 ) VLP
#
# ( 567 / 951 ) ARMK
#
# ( 568 / 951 ) CTT
#
# ( 569 / 951 ) SALT
# no S-1 for  SALT
#
# ( 570 / 951 ) TLOG
#
# ( 571 / 951 ) GLYC
#
# ( 572 / 951 ) AKER
#
# ( 573 / 951 ) SC
#
# ( 574 / 951 ) CRCM
#
# ( 575 / 951 ) DRNA
#
# ( 576 / 951 ) CARA
#
# ( 577 / 951 ) MBUU
#
# ( 578 / 951 ) NWHM
#
# ( 579 / 951 ) RARE
#
# ( 580 / 951 ) QURE
# no S-1 for  QURE
#
# ( 581 / 951 ) GNCA
#
# ( 582 / 951 ) BIOC
#
# ( 583 / 951 ) CBPX
#
# ( 584 / 951 ) EBIO
#
# ( 585 / 951 ) LADR
#
# ( 586 / 951 ) RVNC
#
# ( 587 / 951 ) CNCE
#
# ( 588 / 951 ) SMLR
#
# ( 589 / 951 ) VRNS
#
# ( 590 / 951 ) REPH
#
# ( 591 / 951 ) AKAO
#
# ( 592 / 951 ) GLMD
# no S-1 for  GLMD
#
# ( 593 / 951 ) CSLT
#
# ( 594 / 951 ) PCTY
#
# ( 595 / 951 ) QTWO
#
# ( 596 / 951 ) AKBA
#
# ( 597 / 951 ) MDWD
# no S-1 for  MDWD
#
# ( 598 / 951 ) VSAR
#
# ( 599 / 951 ) TNET
#
# ( 600 / 951 ) TWOU
#
# ( 601 / 951 ) WATT
#
# ( 602 / 951 ) PIH
#
# ( 603 / 951 ) RUBI
#
# ( 604 / 951 ) GRUB
#
# ( 605 / 951 ) LQ
#
# ( 606 / 951 ) ADMS
#
# ( 607 / 951 ) ENBL
#
# ( 608 / 951 ) FPI
#
# ( 609 / 951 ) PAHC
#
# ( 610 / 951 ) PAYC
#
# ( 611 / 951 ) SABR
#
# ( 612 / 951 ) SPWH
#
# ( 613 / 951 ) VTL
#
# ( 614 / 951 ) ALDX
#
# ( 615 / 951 ) FRSH
#
# ( 616 / 951 ) SCYX
# no S-1 for  SCYX
#
# ( 617 / 951 ) GLOP
# no S-1 for  GLOP
#
# ( 618 / 951 ) ALDR
#
# ( 619 / 951 ) CMCM
# no S-1 for  CMCM
#
# ( 620 / 951 ) KTWO
#
# ( 621 / 951 ) LPG
# no S-1 for  LPG
#
# ( 622 / 951 ) PBFX
#
# ( 623 / 951 ) TOUR
# no S-1 for  TOUR
#
# ( 624 / 951 ) OUNZ
#
# ( 625 / 951 ) JMEI
# no S-1 for  JMEI
#
# ( 626 / 951 ) TGEN
#
# ( 627 / 951 ) JD
# no S-1 for  JD
#
# ( 628 / 951 ) PE
#
# ( 629 / 951 ) SDPI
#
# ( 630 / 951 ) RESN
#
# ( 631 / 951 ) ANET
#
# ( 632 / 951 ) RDUS
#
# ( 633 / 951 ) MOBL
#
# ( 634 / 951 ) FELP
#
# ( 635 / 951 ) VNOM
#
# ( 636 / 951 ) GPRO
#
# ( 637 / 951 ) NERV
#
# ( 638 / 951 ) GBIM
#
# ( 639 / 951 ) TERP
#
# ( 640 / 951 ) GLOB
# no S-1 for  GLOB
#
# ( 641 / 951 ) IMDZ
#
# ( 642 / 951 ) PFNX
#
# ( 643 / 951 ) LOCO
#
# ( 644 / 951 ) OCUL
#
# ( 645 / 951 ) OEC
# no S-1 for  OEC
#
# ( 646 / 951 ) SPKE
#
# ( 647 / 951 ) WLKP
#
# ( 648 / 951 ) HQY
# no S-1 for  HQY
#
# ( 649 / 951 ) ORPN
# no S-1 for  ORPN
#
# ( 650 / 951 ) SYF
#
# ( 651 / 951 ) FCB
#
# ( 652 / 951 ) LOXO
#
# ( 653 / 951 ) EARS
# no S-1 for  EARS
#
# ( 654 / 951 ) TTOO
#
# ( 655 / 951 ) HMLP
# no S-1 for  HMLP
#
# ( 656 / 951 ) GNBC
#
# ( 657 / 951 ) OTIC
#
# ( 658 / 951 ) RWLK
# no S-1 for  RWLK
#
# ( 659 / 951 ) FOMX
# no S-1 for  FOMX
#
# ( 660 / 951 ) PRQR
# no S-1 for  PRQR
#
# ( 661 / 951 ) AVAL
# no S-1 for  AVAL
#
# ( 662 / 951 ) CFG
#
# ( 663 / 951 ) CYBR
# no S-1 for  CYBR
#
# ( 664 / 951 ) MDLY
#
# ( 665 / 951 ) TVPT
#
# ( 666 / 951 ) VBLT
# no S-1 for  VBLT
#
# ( 667 / 951 ) VSLR
#
# ( 668 / 951 ) W
#
# ( 669 / 951 ) ATTO
# no S-1 for  ATTO
#
# ( 670 / 951 ) DERM
#
# ( 671 / 951 ) FMSA
#
# ( 672 / 951 ) HUBS
#
# ( 673 / 951 ) USDP
# no S-1 for  USDP
#
# ( 674 / 951 ) DPLO
#
# ( 675 / 951 ) DBVT
# no S-1 for  DBVT
#
# ( 676 / 951 ) PRTO
#
# ( 677 / 951 ) SHLX
#
# ( 678 / 951 ) FSAM
#
# ( 679 / 951 ) AM
#
# ( 680 / 951 ) UPLD
#
# ( 681 / 951 ) TBK
#
# ( 682 / 951 ) FRPT
#
# ( 683 / 951 ) SKYS
# no S-1 for  SKYS
#
# ( 684 / 951 ) PRAH
# ( 685 / 951 ) FGEN
#
# ( 686 / 951 ) LMRK
#
# ( 687 / 951 ) SKIS
#
# ( 688 / 951 ) HSGX
#
# ( 689 / 951 ) LC
# no S-1 for  LC
#
# ( 690 / 951 ) NEWR
#
# ( 691 / 951 ) WK
#
# ( 692 / 951 ) ONDK
#
# ( 693 / 951 ) BLCM
#
# ( 694 / 951 ) ZSAN
#
# ( 695 / 951 ) ASND
# no S-1 for  ASND
#
# ( 696 / 951 ) TCON
#
# ( 697 / 951 ) SHAK
#
# ( 698 / 951 ) AVGR
#
# ( 699 / 951 ) ONCE
#
# ( 700 / 951 ) DEA
#
# ( 701 / 951 ) INOV
#
# ( 702 / 951 ) AJX
#
# ( 703 / 951 ) BLPH
#
# ( 704 / 951 ) TONS
#
# ( 705 / 951 ) SMMT
# no S-1 for  SMMT
#
# ( 706 / 951 ) NCOM
# no S-1 for  NCOM
#
# ( 707 / 951 ) STDY
#
# ( 708 / 951 ) TANH
# no S-1 for  TANH
#
# ( 709 / 951 ) JCAP
#
# ( 710 / 951 ) KRNT
# no S-1 for  KRNT
#
# ( 711 / 951 ) ADRO
#
# ( 712 / 951 ) VIRT
#
# ( 713 / 951 ) EVA
#
# ( 714 / 951 ) BPMC
#
# ( 715 / 951 ) OPGN
#
# ( 716 / 951 ) ADAP
# no S-1 for  ADAP
#
# ( 717 / 951 ) HTGM
#
# ( 718 / 951 ) COLL
#
# ( 719 / 951 ) TEGP
#
# ( 720 / 951 ) BOJA
#
# ( 721 / 951 ) RKDA
#
# ( 722 / 951 ) WING
#
# ( 723 / 951 ) CYAD
# no S-1 for  CYAD
#
# ( 724 / 951 ) LNTH
#
# ( 725 / 951 ) GNRT
#
# ( 726 / 951 ) MCRN
#
# ( 727 / 951 ) CATB
#
# ( 728 / 951 ) GKOS
#
# ( 729 / 951 ) ALRM
#
# ( 730 / 951 ) APPF
#
# ( 731 / 951 ) MCRB
#
# ( 732 / 951 ) CHMA
#
# ( 733 / 951 ) OLLI
#
# ( 734 / 951 ) MCFT
#
# ( 735 / 951 ) BUFF
#
# ( 736 / 951 ) LOB
#
# ( 737 / 951 ) VTVT
#
# ( 738 / 951 ) NTEC
# no S-1 for  NTEC
#
# ( 739 / 951 ) ZYNE
#
# ( 740 / 951 ) PLNT
#
# ( 741 / 951 ) AIMT
#
# ( 742 / 951 ) CNFR
#
# ( 743 / 951 ) RGNX
#
# ( 744 / 951 ) NBRV
# no S-1 for  NBRV
#
# ( 745 / 951 ) ABTX
#
# ( 746 / 951 ) CTMX
#
# ( 747 / 951 ) RACE
# no S-1 for  RACE
#
# ( 748 / 951 ) OASM
# no S-1 for  OASM
#
# ( 749 / 951 ) IOTS
#
# ( 750 / 951 ) MYOK
#
# ( 751 / 951 ) FORK
# no S-1 for  FORK
#
# ( 752 / 951 ) VYGR
#
# ( 753 / 951 ) INST
#
# ( 754 / 951 ) MIME
# no S-1 for  MIME
#
# ( 755 / 951 ) SQ
# no S-1 for  SQ
#
# ( 756 / 951 ) DLTH
#
# ( 757 / 951 ) KTOV
# no S-1 for  KTOV
#
# ( 758 / 951 ) CCRC
#
# ( 759 / 951 ) BGNE
#
# ( 760 / 951 ) CRVS
#
# ( 761 / 951 ) SBPH
#
# ( 762 / 951 ) TPB
#
# ( 763 / 951 ) SITE
#
# ( 764 / 951 ) ACIA
#
# ( 765 / 951 ) PLSE
#
# ( 766 / 951 ) MRUS
# no S-1 for  MRUS
#
# ( 767 / 951 ) MSBI
#
# ( 768 / 951 ) GMS
# no S-1 for  GMS
#
# ( 769 / 951 ) LCAHU
#
# ( 770 / 951 ) RETA
#
# ( 771 / 951 ) USFD
#
# ( 772 / 951 ) CLSD
#
# ( 773 / 951 ) SYRS
#
# ( 774 / 951 ) BOLD
#
# ( 775 / 951 ) TPIC
#
# ( 776 / 951 ) KNSL
#
# ( 777 / 951 ) TCMD
#
# ( 778 / 951 ) TLND
# no S-1 for  TLND
#
# ( 779 / 951 ) GEMP
#
# ( 780 / 951 ) MEDP
#
# ( 781 / 951 ) PTGX
#
# ( 782 / 951 ) EVBG
#
# ( 783 / 951 ) BGFT
# BGFT 'pos'
#
# ( 784 / 951 ) NOVN
#
# ( 785 / 951 ) TTD
# no S-1 for  TTD
#
# ( 786 / 951 ) CSTR
#
# ( 787 / 951 ) ELF
#
# ( 788 / 951 ) VVV
# no S-1 for  VVV
#
# ( 789 / 951 ) ACIU
# no S-1 for  ACIU
#
# ( 790 / 951 ) GSUM
# no S-1 for  GSUM
#
# ( 791 / 951 ) TYHT
#
# ( 792 / 951 ) TRHC
#
# ( 793 / 951 ) ADSW
#
# ( 794 / 951 ) OBLN
#
# ( 795 / 951 ) WAAS
#
# ( 796 / 951 ) CWH
#
# ( 797 / 951 ) MRAM
#
# ( 798 / 951 ) TUSK
#
# ( 799 / 951 ) CRSP
#
# ( 800 / 951 ) FRTA
#
# ( 801 / 951 ) RARX
# no S-1 for  RARX
#
# ( 802 / 951 ) ZTO
# no S-1 for  ZTO
#
# ( 803 / 951 ) MYOV
#
# ( 804 / 951 ) GTYHU
#
# ( 805 / 951 ) BL
#
# ( 806 / 951 ) QTNA
#
# ( 807 / 951 ) IIPR
#
# ( 808 / 951 ) POLA
#
# ( 809 / 951 ) SNES
#
# ( 810 / 951 ) WRD
#
# ( 811 / 951 ) TIG
# no S-1 for  TIG
#
# ( 812 / 951 ) HEBT
# no S-1 for  HEBT
#
# ( 813 / 951 ) FRAC
#
# ( 814 / 951 ) ANAB
#
# ( 815 / 951 ) OBSV
# no S-1 for  OBSV
#
# ( 816 / 951 ) JNCE
#
# ( 817 / 951 ) REVG
#
# ( 818 / 951 ) JELD
#
# ( 819 / 951 ) LAUR
#
# ( 820 / 951 ) KRP
#
# ( 821 / 951 ) METC
#
# ( 822 / 951 ) CLPR
#
# ( 823 / 951 ) FBM
#
# ( 824 / 951 ) SACH
#
# ( 825 / 951 ) SNAP
# no S-1 for  SNAP
#
# ( 826 / 951 ) BYSI
# no S-1 for  BYSI
#
# ( 827 / 951 ) JILL
#
# ( 828 / 951 ) PSDO
#
# ( 829 / 951 ) MULE
#
# ( 830 / 951 ) PUMP
#
# ( 831 / 951 ) TRPX
# no S-1 for  TRPX
#
# ( 832 / 951 ) AYX
#
# ( 833 / 951 ) HESM
#
# ( 834 / 951 ) SNDR
# no S-1 for  SNDR
#
# ( 835 / 951 ) ELVT
#
# ( 836 / 951 ) OKTA
#
# ( 837 / 951 ) NETS
# no S-1 for  NETS
#
# ( 838 / 951 ) TOCA
#
# ( 839 / 951 ) YEXT
#
# ( 840 / 951 ) FND
#
# ( 841 / 951 ) VRNA
# no S-1 for  VRNA
#
# ( 842 / 951 ) CLDR
#
# ( 843 / 951 ) CVNA
#
# ( 844 / 951 ) EEX
#
# ( 845 / 951 ) NCSM
#
# ( 846 / 951 ) XRF
# no S-1 for  XRF
#
# ( 847 / 951 ) ZYME
# no S-1 for  ZYME
#
# ( 848 / 951 ) URGN
# no S-1 for  URGN
#
# ( 849 / 951 ) AMGP
#
# ( 850 / 951 ) BHVN
#
# ( 851 / 951 ) KREF
#
# ( 852 / 951 ) OVID
#
# ( 853 / 951 ) GDI
#
# ( 854 / 951 ) SOI
#
# ( 855 / 951 ) ASV
#
# ( 856 / 951 ) VERI
#
# ( 857 / 951 ) GTHX
#
# ( 858 / 951 ) ARGX
# no S-1 for  ARGX
#
# ( 859 / 951 ) BEDU
# no S-1 for  BEDU
#
# ( 860 / 951 ) WOW
#
# ( 861 / 951 ) APPN
#
# ( 862 / 951 ) SSTI
#
# ( 863 / 951 ) IMRN
# no S-1 for  IMRN
#
# ( 864 / 951 ) ATNX
#
# ( 865 / 951 ) ADOM
#
# ( 866 / 951 ) ATUS
#
# ( 867 / 951 ) GPMT
#
# ( 868 / 951 ) ATXI
#
# ( 869 / 951 ) ESQ
#
# ( 870 / 951 ) MRSN
#
# ( 871 / 951 ) ALRN
#
# ( 872 / 951 ) APRN
#
# ( 873 / 951 ) DOVA
#
# ( 874 / 951 ) TNTR
#
# ( 875 / 951 ) BY
#
# ( 876 / 951 ) SNNA
#
# ( 877 / 951 ) CIFS
# no S-1 for  CIFS
#
# ( 878 / 951 ) TRMT
#
# ( 879 / 951 ) BSTI
# no S-1 for  BSTI
#
# ( 880 / 951 ) CELC
#
# ( 881 / 951 ) DESP
# no S-1 for  DESP
#
# ( 882 / 951 ) KRYS
#
# ( 883 / 951 ) ZLAB
# no S-1 for  ZLAB
#
# ( 884 / 951 ) PETZ
# no S-1 for  PETZ
#
# ( 885 / 951 ) RYB
# no S-1 for  RYB
#
# ( 886 / 951 ) DCPH
#
# ( 887 / 951 ) NCNA
# no S-1 for  NCNA
#
# ( 888 / 951 ) NITE
# no S-1 for  NITE
#
# ( 889 / 951 ) ROKU
# no S-1 for  ROKU
#
# ( 890 / 951 ) RYTM
#
# ( 891 / 951 ) SWCH
# no S-1 for  SWCH
#
# ( 892 / 951 ) KIDS
#
# ( 893 / 951 ) CARG
#
# ( 894 / 951 ) OPTN
#
# ( 895 / 951 ) QD
# no S-1 for  QD
#
# ( 896 / 951 ) MDB
#
# ( 897 / 951 ) LYL
# no S-1 for  LYL
#
# ( 898 / 951 ) REDU
# no S-1 for  REDU
#
# ( 899 / 951 ) FAT
# no S-1 for  FAT
#
# ( 900 / 951 ) ABLX
# no S-1 for  ABLX
#
# ( 901 / 951 ) BPMP
#
# ( 902 / 951 ) EYE
#
# ( 903 / 951 ) SPRO
#
# ( 904 / 951 ) ACMR
#
# ( 905 / 951 ) AQ
# no S-1 for  AQ
#
# ( 906 / 951 ) MCB
#
# ( 907 / 951 ) BRPAU
#
# ( 908 / 951 ) RETO
# no S-1 for  RETO
#
# ( 909 / 951 ) BOXL
#
# ( 910 / 951 ) LACQU
#
# ( 911 / 951 ) CURO
#
# ( 912 / 951 ) QTRX
#
# ( 913 / 951 ) DNLI
#
# ( 914 / 951 ) NMRK
#
# ( 915 / 951 ) LX
# no S-1 for  LX
#
# ( 916 / 951 ) CUE
#
# ( 917 / 951 ) EAGLU
#
# ( 918 / 951 ) ILPT
#
# ( 919 / 951 ) NINE
#
# ( 920 / 951 ) ADT
#
# ( 921 / 951 ) COLD
#
# ( 922 / 951 ) PAGS
# no S-1 for  PAGS
#
# ( 923 / 951 ) EYEN
#
# ( 924 / 951 ) GTES
#
# ( 925 / 951 ) MNLO
#
# ( 926 / 951 ) ARMO
#
# ( 927 / 951 ) SLDB
#
# ( 928 / 951 ) TORC
#
# ( 929 / 951 ) MTECU
#
# ( 930 / 951 ) CAAP
# no S-1 for  CAAP
#
# ( 931 / 951 ) HUD
# no S-1 for  HUD
#
# ( 932 / 951 ) IPIC
# no S-1 for  IPIC
#
# ( 933 / 951 ) SLGL
# no S-1 for  SLGL
#
# ( 934 / 951 ) FTSI
#
# ( 935 / 951 ) CEPU
# no S-1 for  CEPU
#
# ( 936 / 951 ) SSLJ
# no S-1 for  SSLJ
#
# ( 937 / 951 ) WHD
#
# ( 938 / 951 ) EOLS
#
# ( 939 / 951 ) VCTR
#
# ( 940 / 951 ) QES
#
# ( 941 / 951 ) CDLX
#
# ( 942 / 951 ) BFRA
# no S-1 for  BFRA
#
# ( 943 / 951 ) MOTS
#
# ( 944 / 951 ) FAMI
# no S-1 for  FAMI
#
# ( 945 / 951 ) BTAI
#
# ( 946 / 951 ) BWB
#
# ( 947 / 951 ) OPESU
#
# ( 948 / 951 ) RCUS
#
# ( 949 / 951 ) ZS
#
# ( 950 / 951 ) DNJR
# no S-1 for  DNJR
#
# ( 951 / 951 ) DBX
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-1afa68a47753> in <module>()
#      26
#      27 #combine original data with standardized sentiment features
# ---> 28 df1 = pd.concat([standardize(df_sentiment_features), df], axis=1).dropna()
#
# NameError: name 'standardize' is not defined

# %%
df1 = pd.concat([ml.standardize(df_sentiment_features), df], axis=1).dropna()

# %%
#save for later improvements
df1.to_csv('2 sentiment analysis.csv', index=True, index_label='Symbol')

# %%
#feature importance
ml.show_feature_importance(df1, '3M')

# %%
#now run ML flow with sentiment features
ml.run_ml_flow(df1)
# Out:
#                 1D        1W        1M        3M
# AUC       0.531046  0.526413  0.496314  0.508410
# f1        0.606061  0.610778  0.638298  0.677083
# log loss  0.707982  0.740833  0.692042  0.667043
