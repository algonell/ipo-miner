# %% [markdown]
# # Summarization
# - Summarize S-1 raw filings
# - Batch process

# %%
#core
import pandas as pd

from bs4 import BeautifulSoup
from pathlib import Path

#NLP
from gensim.summarization import summarize
# Out:
# C:\Users\Void\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# # Summarize IPO S-1 Filings

# %%
#load previous progress
df = pd.read_csv('../Datasets/2 sentiment analysis.csv', index_col='Symbol')

# %%
def summarize_symbol(x):
    #read S-1
    with open("../Data/" + x + ".htm", "r", encoding="utf-8") as f:
        html = f.read()
        soup = BeautifulSoup(html,"html5lib")
        text = soup.get_text(strip=True)

        #summary and keywords
        summary = summarize(text[:250000], ratio=0.01)
        
        #write summary
        with open("../Summary/" + x + ".txt", "w", encoding="utf-8") as f:
            f.write(summary)

# %%
#batch process
counter = 0

for x in df.index:
    try:
        counter += 1
        print('\n( ' + str(counter) + ' / ' + str(df.shape[0]) + ' ) ' + str(x))

        #check if exists
        if Path("../Summary/" + x + ".txt").is_file():
            print(x + ' data already exists, skipping...')
            continue

        #summarization and keywords
        summarize_symbol(x)
    except Exception as e:
        print(x, e)
        #for now expection are only too large files that cause out of memory
        #anyway it's imposible to summarize so then write empty files for later jobs
        #Path('./Summary/' + x + '.txt').touch()
# Out:
# ( 1 / 700 ) AACC
# AACC data already exists, skipping...
#
# ( 2 / 700 ) AAT
# AAT data already exists, skipping...
#
# ( 3 / 700 ) ABR
# ABR data already exists, skipping...
#
# ( 4 / 700 ) ABTX
# ABTX data already exists, skipping...
#
# ( 5 / 700 ) ACAD
# ACAD data already exists, skipping...
#
# ( 6 / 700 ) ACFC
# ACFC data already exists, skipping...
#
# ( 7 / 700 ) ACIA
# ACIA data already exists, skipping...
#
# ( 8 / 700 ) ACMR
# ACMR data already exists, skipping...
#
# ( 9 / 700 ) ACOR
# ACOR data already exists, skipping...
#
# ( 10 / 700 ) ACRX
# ACRX data already exists, skipping...
#
# ( 11 / 700 ) ACUS
# ACUS data already exists, skipping...
#
# ( 12 / 700 ) ADMS
# ADMS data already exists, skipping...
#
# ( 13 / 700 ) ADOM
# ADOM data already exists, skipping...
#
# ( 14 / 700 ) ADRO
# ADRO data already exists, skipping...
#
# ( 15 / 700 ) ADSW
# ADSW data already exists, skipping...
#
# ( 16 / 700 ) ADT
# ADT data already exists, skipping...
#
# ( 17 / 700 ) ADUS
# ADUS data already exists, skipping...
#
# ( 18 / 700 ) AEL
# AEL data already exists, skipping...
#
# ( 19 / 700 ) AERI
# AERI data already exists, skipping...
#
# ( 20 / 700 ) AFFY
# AFFY data already exists, skipping...
#
# ( 21 / 700 ) AFH
# AFH data already exists, skipping...
#
# ( 22 / 700 ) AIMC
# AIMC data already exists, skipping...
#
# ( 23 / 700 ) AIMT
# AIMT data already exists, skipping...
#
# ( 24 / 700 ) AIZ
# AIZ data already exists, skipping...
#
# ( 25 / 700 ) AJX
# AJX data already exists, skipping...
#
# ( 26 / 700 ) AKAO
# AKAO data already exists, skipping...
#
# ( 27 / 700 ) AKBA
# AKBA data already exists, skipping...
#
# ( 28 / 700 ) AKER
# AKER data already exists, skipping...
#
# ( 29 / 700 ) AL
# AL data already exists, skipping...
#
# ( 30 / 700 ) ALDR
# ALDR data already exists, skipping...
#
# ( 31 / 700 ) ALDX
# ALDX data already exists, skipping...
#
# ( 32 / 700 ) ALGT
# ALGT data already exists, skipping...
#
# ( 33 / 700 ) ALRM
# ALRM data already exists, skipping...
#
# ( 34 / 700 ) ALRN
# ALRN data already exists, skipping...
#
# ( 35 / 700 ) ALSN
# ALSN data already exists, skipping...
#
# ( 36 / 700 ) AM
# AM data already exists, skipping...
#
# ( 37 / 700 ) AMBA
# AMBA data already exists, skipping...
#
# ( 38 / 700 ) AMGP
# AMGP data already exists, skipping...
#
# ( 39 / 700 ) ANAB
# ANAB data already exists, skipping...
#
# ( 40 / 700 ) ANET
# ANET data already exists, skipping...
#
# ( 41 / 700 ) ANGI
# ANGI data already exists, skipping...
#
# ( 42 / 700 ) ANTH
# ANTH data already exists, skipping...
#
# ( 43 / 700 ) APAM
# APAM data already exists, skipping...
#
# ( 44 / 700 ) APEI
# APEI data already exists, skipping...
#
# ( 45 / 700 ) APKT
# APKT data already exists, skipping...
#
# ( 46 / 700 ) APO
# APO data already exists, skipping...
#
# ( 47 / 700 ) APPF
# APPF data already exists, skipping...
#
# ( 48 / 700 ) APPN
# APPN data already exists, skipping...
#
# ( 49 / 700 ) APRN
# APRN data already exists, skipping...
#
# ( 50 / 700 ) ARMK
# ARMK data already exists, skipping...
#
# ( 51 / 700 ) ARMO
# ARMO data already exists, skipping...
#
# ( 52 / 700 ) ARYX
# ARYX data already exists, skipping...
#
# ( 53 / 700 ) ASV
# ASV data already exists, skipping...
#
# ( 54 / 700 ) ATNX
# ATNX data already exists, skipping...
#
# ( 55 / 700 ) ATUS
# ATUS data already exists, skipping...
#
# ( 56 / 700 ) ATXI
# ATXI data already exists, skipping...
#
# ( 57 / 700 ) AUTH
# AUTH data already exists, skipping...
#
# ( 58 / 700 ) AVAV
# AVAV data already exists, skipping...
#
# ( 59 / 700 ) AVEO
# AVEO data already exists, skipping...
#
# ( 60 / 700 ) AVGR
# AVGR data already exists, skipping...
#
# ( 61 / 700 ) AYX
# AYX data already exists, skipping...
#
# ( 62 / 700 ) BAS
# BAS data already exists, skipping...
#
# ( 63 / 700 ) BBGI
# BBGI data already exists, skipping...
#
# ( 64 / 700 ) BBRG
# BBRG data already exists, skipping...
#
# ( 65 / 700 ) BBW
# BBW data already exists, skipping...
#
# ( 66 / 700 ) BCC
# BCC data already exists, skipping...
#
# ( 67 / 700 ) BCEI
# BCEI data already exists, skipping...
#
# ( 68 / 700 ) BCOV
# BCOV data already exists, skipping...
#
# ( 69 / 700 ) BCRH
# BCRH data already exists, skipping...
#
# ( 70 / 700 ) BDRY
#
# ( 71 / 700 ) BEAT
# BEAT data already exists, skipping...
#
# ( 72 / 700 ) BECN
# BECN data already exists, skipping...
#
# ( 73 / 700 ) BERY
# BERY data already exists, skipping...
#
# ( 74 / 700 ) BFAM
# BFAM data already exists, skipping...
#
# ( 75 / 700 ) BFED
# BFED data already exists, skipping...
#
# ( 76 / 700 ) BGFV
# BGFV data already exists, skipping...
#
# ( 77 / 700 ) BGMD
# BGMD data already exists, skipping...
#
# ( 78 / 700 ) BGNE
# BGNE data already exists, skipping...
#
# ( 79 / 700 ) BHVN
# BHVN data already exists, skipping...
#
# ( 80 / 700 ) BIOC
# BIOC data already exists, skipping...
#
# ( 81 / 700 ) BKD
# BKD data already exists, skipping...
#
# ( 82 / 700 ) BKU
# BKU data already exists, skipping...
#
# ( 83 / 700 ) BL
# BL data already exists, skipping...
#
# ( 84 / 700 ) BLCM
# BLCM data already exists, skipping...
#
# ( 85 / 700 ) BLMN
# BLMN data already exists, skipping...
#
# ( 86 / 700 ) BLPH
# BLPH data already exists, skipping...
#
# ( 87 / 700 ) BMTI
# BMTI data already exists, skipping...
#
# ( 88 / 700 ) BNCL
# BNCL data already exists, skipping...
#
# ( 89 / 700 ) BNFT
# BNFT data already exists, skipping...
#
# ( 90 / 700 ) BNO
# BNO data already exists, skipping...
#
# ( 91 / 700 ) BOJA
# BOJA data already exists, skipping...
#
# ( 92 / 700 ) BOLD
# BOLD data already exists, skipping...
#
# ( 93 / 700 ) BOXL
# BOXL data already exists, skipping...
#
# ( 94 / 700 ) BPMC
# BPMC data already exists, skipping...
#
# ( 95 / 700 ) BPMP
# BPMP data already exists, skipping...
#
# ( 96 / 700 ) BRPAU
# BRPAU data already exists, skipping...
#
# ( 97 / 700 ) BRSS
# BRSS data already exists, skipping...
#
# ( 98 / 700 ) BRX
# BRX data already exists, skipping...
#
# ( 99 / 700 ) BTAI
# BTAI data already exists, skipping...
#
# ( 100 / 700 ) BUFF
# BUFF data already exists, skipping...
#
# ( 101 / 700 ) BWB
# BWB data already exists, skipping...
#
# ( 102 / 700 ) BY
# BY data already exists, skipping...
#
# ( 103 / 700 ) CALX
# CALX data already exists, skipping...
#
# ( 104 / 700 ) CANE
# CANE data already exists, skipping...
#
# ( 105 / 700 ) CAPB
# CAPB data already exists, skipping...
#
# ( 106 / 700 ) CARA
# CARA data already exists, skipping...
#
# ( 107 / 700 ) CARB
# CARB data already exists, skipping...
#
# ( 108 / 700 ) CARG
# CARG data already exists, skipping...
#
# ( 109 / 700 ) CATB
# CATB data already exists, skipping...
#
# ( 110 / 700 ) CAVM
# CAVM data already exists, skipping...
#
# ( 111 / 700 ) CBOE
# CBOE data already exists, skipping...
#
# ( 112 / 700 ) CBOU
# CBOU data already exists, skipping...
#
# ( 113 / 700 ) CBPX
# CBPX data already exists, skipping...
#
# ( 114 / 700 ) CCCR
# CCCR data already exists, skipping...
#
# ( 115 / 700 ) CCRC
# CCRC data already exists, skipping...
#
# ( 116 / 700 ) CDLX
# CDLX data already exists, skipping...
#
# ( 117 / 700 ) CELC
# CELC data already exists, skipping...
#
# ( 118 / 700 ) CFG
# CFG data already exists, skipping...
#
# ( 119 / 700 ) CGIX
# CGIX data already exists, skipping...
#
# ( 120 / 700 ) CHCI
# CHCI data already exists, skipping...
#
# ( 121 / 700 ) CHEF
# CHEF data already exists, skipping...
#
# ( 122 / 700 ) CHGG
# CHGG data already exists, skipping...
#
# ( 123 / 700 ) CHMA
# CHMA data already exists, skipping...
#
# ( 124 / 700 ) CHMI
# CHMI data already exists, skipping...
#
# ( 125 / 700 ) CHUY
# CHUY data already exists, skipping...
#
# ( 126 / 700 ) CLDR
# CLDR data already exists, skipping...
#
# ( 127 / 700 ) CLNE
# CLNE data already exists, skipping...
#
# ( 128 / 700 ) CLPR
# CLPR data already exists, skipping...
#
# ( 129 / 700 ) CLSD
# CLSD data already exists, skipping...
#
# ( 130 / 700 ) CLUB
# CLUB data already exists, skipping...
#
# ( 131 / 700 ) CLVS
# CLVS data already exists, skipping...
#
# ( 132 / 700 ) CLWR
# CLWR data already exists, skipping...
#
# ( 133 / 700 ) CME
# CME data already exists, skipping...
#
# ( 134 / 700 ) CMG
# CMG data already exists, skipping...
#
# ( 135 / 700 ) CMP
# CMP data already exists, skipping...
#
# ( 136 / 700 ) CMRX
# CMRX data already exists, skipping...
#
# ( 137 / 700 ) CNAT
# CNAT data already exists, skipping...
#
# ( 138 / 700 ) CNCE
# CNCE data already exists, skipping...
#
# ( 139 / 700 ) CNFR
# CNFR data already exists, skipping...
#
# ( 140 / 700 ) CNK
# CNK data already exists, skipping...
#
# ( 141 / 700 ) CNSL
# CNSL data already exists, skipping...
#
# ( 142 / 700 ) COLD
# COLD data already exists, skipping...
#
# ( 143 / 700 ) COLL
# COLL data already exists, skipping...
#
# ( 144 / 700 ) COMM
# COMM data already exists, skipping...
#
# ( 145 / 700 ) CONN
# CONN data already exists, skipping...
#
# ( 146 / 700 ) COR
# COR data already exists, skipping...
#
# ( 147 / 700 ) CORN
# CORN data already exists, skipping...
#
# ( 148 / 700 ) CPRX
# CPRX data already exists, skipping...
#
# ( 149 / 700 ) CPSI
# CPSI data already exists, skipping...
#
# ( 150 / 700 ) CQP
# CQP data already exists, skipping...
#
# ( 151 / 700 ) CRCM
# CRCM data already exists, skipping...
#
# ( 152 / 700 ) CRM
# CRM data already exists, skipping...
#
# ( 153 / 700 ) CROX
# CROX data already exists, skipping...
#
# ( 154 / 700 ) CRSP
# CRSP data already exists, skipping...
#
# ( 155 / 700 ) CRTX
# CRTX data already exists, skipping...
#
# ( 156 / 700 ) CRUD
# CRUD data already exists, skipping...
#
# ( 157 / 700 ) CRVS
# CRVS data already exists, skipping...
#
# ( 158 / 700 ) CSE
# CSE data already exists, skipping...
#
# ( 159 / 700 ) CSLT
# CSLT data already exists, skipping...
#
# ( 160 / 700 ) CSOD
# CSOD data already exists, skipping...
#
# ( 161 / 700 ) CSTR
# CSTR data already exists, skipping...
#
# ( 162 / 700 ) CTMX
# CTMX data already exists, skipping...
#
# ( 163 / 700 ) CTRN
# CTRN data already exists, skipping...
#
# ( 164 / 700 ) CTT
# CTT data already exists, skipping...
#
# ( 165 / 700 ) CUE
# CUE data already exists, skipping...
#
# ( 166 / 700 ) CURO
# CURO data already exists, skipping...
#
# ( 167 / 700 ) CUTR
# CUTR data already exists, skipping...
#
# ( 168 / 700 ) CVI
# CVI data already exists, skipping...
#
# ( 169 / 700 ) CVLT
# CVLT data already exists, skipping...
#
# ( 170 / 700 ) CVNA
# CVNA data already exists, skipping...
#
# ( 171 / 700 ) CVRR
# CVRR data already exists, skipping...
#
# ( 172 / 700 ) CWH
# CWH data already exists, skipping...
#
# ( 173 / 700 ) DATA
# DATA data already exists, skipping...
#
# ( 174 / 700 ) DBA
# DBA data already exists, skipping...
#
# ( 175 / 700 ) DBX
# DBX data already exists, skipping...
#
# ( 176 / 700 ) DCPH
# DCPH data already exists, skipping...
#
# ( 177 / 700 ) DEA
# DEA data already exists, skipping...
#
# ( 178 / 700 ) DERM
# DERM data already exists, skipping...
#
# ( 179 / 700 ) DG
# DG data already exists, skipping...
#
# ( 180 / 700 ) DK
# DK data already exists, skipping...
#
# ( 181 / 700 ) DKL
# DKL data already exists, skipping...
#
# ( 182 / 700 ) DKS
# DKS data already exists, skipping...
#
# ( 183 / 700 ) DLB
# DLB data already exists, skipping...
#
# ( 184 / 700 ) DLPH
# DLPH data already exists, skipping...
#
# ( 185 / 700 ) DLTH
# DLTH data already exists, skipping...
#
# ( 186 / 700 ) DNKN
# DNKN data already exists, skipping...
#
# ( 187 / 700 ) DNLI
# DNLI data already exists, skipping...
#
# ( 188 / 700 ) DNO
# DNO data already exists, skipping...
#
# ( 189 / 700 ) DOVA
# DOVA data already exists, skipping...
#
# ( 190 / 700 ) DPLO
# DPLO data already exists, skipping...
#
# ( 191 / 700 ) DRAD
# DRAD data already exists, skipping...
#
# ( 192 / 700 ) DRH
# DRH data already exists, skipping...
#
# ( 193 / 700 ) DRNA
# DRNA data already exists, skipping...
#
# ( 194 / 700 ) DUF
# DUF data already exists, skipping...
#
# ( 195 / 700 ) DVAX
# DVAX data already exists, skipping...
#
# ( 196 / 700 ) DXCM
# DXCM data already exists, skipping...
#
# ( 197 / 700 ) EAGLU
# EAGLU data already exists, skipping...
#
# ( 198 / 700 ) EARN
# EARN data already exists, skipping...
#
# ( 199 / 700 ) EBIO
# EBIO data already exists, skipping...
#
# ( 200 / 700 ) EBS
# EBS data already exists, skipping...
#
# ( 201 / 700 ) EBSB
# EBSB data already exists, skipping...
#
# ( 202 / 700 ) ECHO
# ECHO data already exists, skipping...
#
# ( 203 / 700 ) ECOM
# ECOM data already exists, skipping...
#
# ( 204 / 700 ) ECT
# ECT data already exists, skipping...
#
# ( 205 / 700 ) ECYT
# ECYT data already exists, skipping...
#
# ( 206 / 700 ) EEX
# EEX data already exists, skipping...
#
# ( 207 / 700 ) ELF
# ELF data already exists, skipping...
#
# ( 208 / 700 ) ELLI
# ELLI data already exists, skipping...
#
# ( 209 / 700 ) ELMD
# ELMD data already exists, skipping...
#
# ( 210 / 700 ) ELVT
# ELVT data already exists, skipping...
#
# ( 211 / 700 ) ENBL
# ENBL data already exists, skipping...
#
# ( 212 / 700 ) ENPH
# ENPH data already exists, skipping...
#
# ( 213 / 700 ) ENSG
# ENSG data already exists, skipping...
#
# ( 214 / 700 ) ENTA
# ENTA data already exists, skipping...
#
# ( 215 / 700 ) EOLS
# EOLS data already exists, skipping...
#
# ( 216 / 700 ) EQM
# EQM data already exists, skipping...
#
# ( 217 / 700 ) ERII
# ERII data already exists, skipping...
#
# ( 218 / 700 ) ESNT
# ESNT data already exists, skipping...
#
# ( 219 / 700 ) ESQ
# ESQ data already exists, skipping...
#
# ( 220 / 700 ) ESRT
# ESRT data already exists, skipping...
#
# ( 221 / 700 ) ETE
# ETE data already exists, skipping...
#
# ( 222 / 700 ) EVA
# EVA data already exists, skipping...
#
# ( 223 / 700 ) EVBG
# EVBG data already exists, skipping...
#
# ( 224 / 700 ) EVC
# EVC data already exists, skipping...
#
# ( 225 / 700 ) EVEP
# EVEP data already exists, skipping...
#
# ( 226 / 700 ) EVHC
# EVHC data already exists, skipping...
#
# ( 227 / 700 ) EVTC
# EVTC data already exists, skipping...
#
# ( 228 / 700 ) EYE
# EYE data already exists, skipping...
#
# ( 229 / 700 ) EYEN
# EYEN data already exists, skipping...
#
# ( 230 / 700 ) FBM
# FBM data already exists, skipping...
#
# ( 231 / 700 ) FCB
# FCB data already exists, skipping...
#
# ( 232 / 700 ) FELP
# FELP data already exists, skipping...
#
# ( 233 / 700 ) FET
# FET data already exists, skipping...
#
# ( 234 / 700 ) FEYE
# FEYE data already exists, skipping...
#
# ( 235 / 700 ) FGEN
# FGEN data already exists, skipping...
#
# ( 236 / 700 ) FIXX
# ( 237 / 700 ) FMI
# FMI data already exists, skipping...
#
# ( 238 / 700 ) FMSA
# FMSA data already exists, skipping...
#
# ( 239 / 700 ) FN
# FN data already exists, skipping...
#
# ( 240 / 700 ) FND
# FND data already exists, skipping...
#
# ( 241 / 700 ) FNGN
# FNGN data already exists, skipping...
#
# ( 242 / 700 ) FOLD
# FOLD data already exists, skipping...
#
# ( 243 / 700 ) FORM
# FORM data already exists, skipping...
#
# ( 244 / 700 ) FOXF
# FOXF data already exists, skipping...
#
# ( 245 / 700 ) FPI
# FPI data already exists, skipping...
#
# ( 246 / 700 ) FPRX
# FPRX data already exists, skipping...
#
# ( 247 / 700 ) FRAC
# FRAC data already exists, skipping...
#
# ( 248 / 700 ) FRAN
# FRAN data already exists, skipping...
#
# ( 249 / 700 ) FRPT
# FRPT data already exists, skipping...
#
# ( 250 / 700 ) FRSH
# FRSH data already exists, skipping...
#
# ( 251 / 700 ) FRTA
# FRTA data already exists, skipping...
#
# ( 252 / 700 ) FSAM
# FSAM data already exists, skipping...
#
# ( 253 / 700 ) FSBW
# FSBW data already exists, skipping...
#
# ( 254 / 700 ) FSLR
# FSLR data already exists, skipping...
#
# ( 255 / 700 ) FTSI
# FTSI data already exists, skipping...
#
# ( 256 / 700 ) GBIM
# GBIM data already exists, skipping...
#
# ( 257 / 700 ) GCAP
# GCAP data already exists, skipping...
#
# ( 258 / 700 ) GCC
# GCC data already exists, skipping...
#
# ( 259 / 700 ) GDI
# GDI data already exists, skipping...
#
# ( 260 / 700 ) GDOT
# GDOT data already exists, skipping...
#
# ( 261 / 700 ) GEMP
# GEMP data already exists, skipping...
#
# ( 262 / 700 ) GEVO
# GEVO data already exists, skipping...
#
# ( 263 / 700 ) GHL
# GHL data already exists, skipping...
#
# ( 264 / 700 ) GKOS
# GKOS data already exists, skipping...
#
# ( 265 / 700 ) GLTR
# GLTR data already exists, skipping...
#
# ( 266 / 700 ) GLUU
# GLUU data already exists, skipping...
#
# ( 267 / 700 ) GLYC
# GLYC data already exists, skipping...
#
# ( 268 / 700 ) GM
# GM data already exists, skipping...
#
# ( 269 / 700 ) GMED
# GMED data already exists, skipping...
#
# ( 270 / 700 ) GMET
# GMET data already exists, skipping...
#
# ( 271 / 700 ) GNBC
# GNBC data already exists, skipping...
#
# ( 272 / 700 ) GNC
# GNC data already exists, skipping...
#
# ( 273 / 700 ) GNCA
# GNCA data already exists, skipping...
#
# ( 274 / 700 ) GNMK
# GNMK data already exists, skipping...
#
# ( 275 / 700 ) GNRT
# GNRT data already exists, skipping...
#
# ( 276 / 700 ) GOGO
# GOGO data already exists, skipping...
#
# ( 277 / 700 ) GOOG
# GOOG data already exists, skipping...
#
# ( 278 / 700 ) GPMT
# GPMT data already exists, skipping...
#
# ( 279 / 700 ) GPRO
# GPRO data already exists, skipping...
#
# ( 280 / 700 ) GRPN
# GRPN data already exists, skipping...
#
# ( 281 / 700 ) GRUB
# GRUB data already exists, skipping...
#
# ( 282 / 700 ) GSG
# GSG data already exists, skipping...
#
# ( 283 / 700 ) GSM
# GSM data already exists, skipping...
#
# ( 284 / 700 ) GTES
# GTES data already exists, skipping...
#
# ( 285 / 700 ) GTHX
# GTHX data already exists, skipping...
#
# ( 286 / 700 ) GTLS
# GTLS data already exists, skipping...
#
# ( 287 / 700 ) GTS
# GTS data already exists, skipping...
#
# ( 288 / 700 ) GTXI
# GTXI data already exists, skipping...
#
# ( 289 / 700 ) GTYHU
# GTYHU data already exists, skipping...
#
# ( 290 / 700 ) HCCI
# HCCI data already exists, skipping...
#
# ( 291 / 700 ) HCLP
# HCLP data already exists, skipping...
#
# ( 292 / 700 ) HDS
# HDS data already exists, skipping...
#
# ( 293 / 700 ) HEES
# HEES data already exists, skipping...
#
# ( 294 / 700 ) HEP
# HEP data already exists, skipping...
#
# ( 295 / 700 ) HESM
# HESM data already exists, skipping...
#
# ( 296 / 700 ) HMHC
# HMHC data already exists, skipping...
#
# ( 297 / 700 ) HMST
# HMST data already exists, skipping...
#
# ( 298 / 700 ) HPP
# HPP data already exists, skipping...
#
# ( 299 / 700 ) HSGX
# HSGX data already exists, skipping...
#
# ( 300 / 700 ) HTGM
# HTGM data already exists, skipping...
#
# ( 301 / 700 ) HTZ
# HTZ data already exists, skipping...
#
# ( 302 / 700 ) HUBS
# HUBS data already exists, skipping...
#
# ( 303 / 700 ) HURN
# HURN data already exists, skipping...
#
# ( 304 / 700 ) HWCC
# HWCC data already exists, skipping...
#
# ( 305 / 700 ) ICPT
# ICPT data already exists, skipping...
#
# ( 306 / 700 ) IIPR
# IIPR data already exists, skipping...
#
# ( 307 / 700 ) ILPT
# ILPT data already exists, skipping...
#
# ( 308 / 700 ) IMDZ
# IMDZ data already exists, skipping...
#
# ( 309 / 700 ) IMI
# IMI data already exists, skipping...
#
# ( 310 / 700 ) INN
# INN data already exists, skipping...
#
# ( 311 / 700 ) INOV
# INOV data already exists, skipping...
#
# ( 312 / 700 ) INST
# INST data already exists, skipping...
#
# ( 313 / 700 ) INTX
# INTX data already exists, skipping...
#
# ( 314 / 700 ) IOTS
# IOTS data already exists, skipping...
#
# ( 315 / 700 ) JBLU
# JBLU data already exists, skipping...
#
# ( 316 / 700 ) JCAP
# JCAP data already exists, skipping...
#
# ( 317 / 700 ) JELD
# JELD data already exists, skipping...
#
# ( 318 / 700 ) JILL
# JILL data already exists, skipping...
#
# ( 319 / 700 ) JMP
# JMP data already exists, skipping...
#
# ( 320 / 700 ) JNCE
# JNCE data already exists, skipping...
#
# ( 321 / 700 ) JONE
# JONE data already exists, skipping...
#
# ( 322 / 700 ) KIDS
# KIDS data already exists, skipping...
#
# ( 323 / 700 ) KNL
# KNL data already exists, skipping...
#
# ( 324 / 700 ) KNSL
# KNSL data already exists, skipping...
#
# ( 325 / 700 ) KONA
# KONA data already exists, skipping...
#
# ( 326 / 700 ) KOP
# KOP data already exists, skipping...
#
# ( 327 / 700 ) KOS
# KOS data already exists, skipping...
#
# ( 328 / 700 ) KPTI
# KPTI data already exists, skipping...
#
# ( 329 / 700 ) KREF
# KREF data already exists, skipping...
#
# ( 330 / 700 ) KRNY
# KRNY data already exists, skipping...
#
# ( 331 / 700 ) KRP
# KRP data already exists, skipping...
#
# ( 332 / 700 ) KRYS
# KRYS data already exists, skipping...
#
# ( 333 / 700 ) KTWO
# KTWO data already exists, skipping...
#
# ( 334 / 700 ) KYAK
# KYAK data already exists, skipping...
#
# ( 335 / 700 ) LACQU
# LACQU data already exists, skipping...
#
# ( 336 / 700 ) LADR
# LADR data already exists, skipping...
#
# ( 337 / 700 ) LAND
# LAND data already exists, skipping...
#
# ( 338 / 700 ) LAUR
# LAUR data already exists, skipping...
#
# ( 339 / 700 ) LCAHU
# LCAHU data already exists, skipping...
#
# ( 340 / 700 ) LIWA
# LIWA data already exists, skipping...
#
# ( 341 / 700 ) LLNW
# LLNW data already exists, skipping...
#
# ( 342 / 700 ) LMAT
# LMAT data already exists, skipping...
#
# ( 343 / 700 ) LMRK
# LMRK data already exists, skipping...
#
# ( 344 / 700 ) LNTH
# LNTH data already exists, skipping...
#
# ( 345 / 700 ) LOB
# LOB data already exists, skipping...
#
# ( 346 / 700 ) LOCO
# LOCO data already exists, skipping...
#
# ( 347 / 700 ) LOGM
# LOGM data already exists, skipping...
#
# ( 348 / 700 ) LOPE
# LOPE data already exists, skipping...
#
# ( 349 / 700 ) LOV
# LOV data already exists, skipping...
#
# ( 350 / 700 ) LOXO
# LOXO data already exists, skipping...
#
# ( 351 / 700 ) LPI
# LPI data already exists, skipping...
#
# ( 352 / 700 ) LPLA
# LPLA data already exists, skipping...
#
# ( 353 / 700 ) LQ
# LQ data already exists, skipping...
#
# ( 354 / 700 ) LQMT
# LQMT data already exists, skipping...
#
# ( 355 / 700 ) LSE
# LSE data already exists, skipping...
#
# ( 356 / 700 ) LULU
# LULU data already exists, skipping...
#
# ( 357 / 700 ) MA
# MA data already exists, skipping...
#
# ( 358 / 700 ) MACK
# MACK data already exists, skipping...
#
# ( 359 / 700 ) MANT
# MANT data already exists, skipping...
#
# ( 360 / 700 ) MAPP
# MAPP data already exists, skipping...
#
# ( 361 / 700 ) MASI
# MASI data already exists, skipping...
#
# ( 362 / 700 ) MBII
# MBII data already exists, skipping...
#
# ( 363 / 700 ) MBUU
# MBUU data already exists, skipping...
#
# ( 364 / 700 ) MCB
# MCB data already exists, skipping...
#
# ( 365 / 700 ) MCEP
# MCEP data already exists, skipping...
#
# ( 366 / 700 ) MCFT
# MCFT data already exists, skipping...
#
# ( 367 / 700 ) MCRB
# MCRB data already exists, skipping...
#
# ( 368 / 700 ) MCRN
# MCRN data already exists, skipping...
#
# ( 369 / 700 ) MDB
# MDB data already exists, skipping...
#
# ( 370 / 700 ) MDLY
# MDLY data already exists, skipping...
#
# ( 371 / 700 ) MDSO
# MDSO data already exists, skipping...
#
# ( 372 / 700 ) MDTH
# MDTH data already exists, skipping...
#
# ( 373 / 700 ) MEDP
# MEDP data already exists, skipping...
#
# ( 374 / 700 ) MELI
# MELI data already exists, skipping...
#
# ( 375 / 700 ) METC
# METC data already exists, skipping...
#
# ( 376 / 700 ) MG
# MG data already exists, skipping...
#
# ( 377 / 700 ) MGNX
# MGNX data already exists, skipping...
#
# ( 378 / 700 ) MHLD
# MHLD data already exists, skipping...
#
# ( 379 / 700 ) MIC
# MIC data already exists, skipping...
#
# ( 380 / 700 ) MKTG
# MKTG data already exists, skipping...
#
# ( 381 / 700 ) MKTX
# MKTX data already exists, skipping...
#
# ( 382 / 700 ) MLNX
# MLNX data already exists, skipping...
#
# ( 383 / 700 ) MMI
# MMI data already exists, skipping...
#
# ( 384 / 700 ) MNKD
# MNKD data already exists, skipping...
#
# ( 385 / 700 ) MNLO
# MNLO data already exists, skipping...
#
# ( 386 / 700 ) MNTA
# MNTA data already exists, skipping...
#
# ( 387 / 700 ) MOBL
# MOBL data already exists, skipping...
#
# ( 388 / 700 ) MODN
# MODN data already exists, skipping...
#
# ( 389 / 700 ) MOH
# MOH data already exists, skipping...
#
# ( 390 / 700 ) MON
# MON data already exists, skipping...
#
# ( 391 / 700 ) MORN
# MORN data already exists, skipping...
#
# ( 392 / 700 ) MOTS
# MOTS data already exists, skipping...
#
# ( 393 / 700 ) MPO
# MPO data already exists, skipping...
#
# ( 394 / 700 ) MPW
# MPW data already exists, skipping...
#
# ( 395 / 700 ) MRAM
# MRAM data already exists, skipping...
#
# ( 396 / 700 ) MRC
# MRC data already exists, skipping...
#
# ( 397 / 700 ) MRIN
# MRIN data already exists, skipping...
#
# ( 398 / 700 ) MRLN
# MRLN data already exists, skipping...
#
# ( 399 / 700 ) MRSN
# MRSN data already exists, skipping...
#
# ( 400 / 700 ) MSBI
# MSBI data already exists, skipping...
#
# ( 401 / 700 ) MTECU
# MTECU data already exists, skipping...
#
# ( 402 / 700 ) MULE
# MULE data already exists, skipping...
#
# ( 403 / 700 ) MX
# MX data already exists, skipping...
#
# ( 404 / 700 ) MXL
# MXL data already exists, skipping...
#
# ( 405 / 700 ) MYOK
# MYOK data already exists, skipping...
#
# ( 406 / 700 ) MYOV
# MYOV data already exists, skipping...
#
# ( 407 / 700 ) NAGS
# NAGS data already exists, skipping...
#
# ( 408 / 700 ) NBHC
# NBHC data already exists, skipping...
#
# ( 409 / 700 ) NBY
# NBY data already exists, skipping...
#
# ( 410 / 700 ) NCLH
# NCLH data already exists, skipping...
#
# ( 411 / 700 ) NCMI
# NCMI data already exists, skipping...
#
# ( 412 / 700 ) NCSM
# NCSM data already exists, skipping...
#
# ( 413 / 700 ) NDLS
# NDLS data already exists, skipping...
#
# ( 414 / 700 ) NDRO
# NDRO data already exists, skipping...
#
# ( 415 / 700 ) NERV
# NERV data already exists, skipping...
#
# ( 416 / 700 ) NEWR
# NEWR data already exists, skipping...
#
# ( 417 / 700 ) NFBK
# NFBK data already exists, skipping...
#
# ( 418 / 700 ) NFLX
# NFLX data already exists, skipping...
#
# ( 419 / 700 ) NFP
# NFP data already exists, skipping...
#
# ( 420 / 700 ) NGS
# NGS data already exists, skipping...
#
# ( 421 / 700 ) NGVC
# NGVC data already exists, skipping...
#
# ( 422 / 700 ) NINE
# NINE data already exists, skipping...
#
# ( 423 / 700 ) NMRK
# NMRK data already exists, skipping...
#
# ( 424 / 700 ) NOVN
# NOVN data already exists, skipping...
#
# ( 425 / 700 ) NOW
# NOW data already exists, skipping...
#
# ( 426 / 700 ) NSM
# NSM data already exists, skipping...
#
# ( 427 / 700 ) NSTG
# NSTG data already exists, skipping...
#
# ( 428 / 700 ) NTGR
# NTGR data already exists, skipping...
#
# ( 429 / 700 ) NWHM
# NWHM data already exists, skipping...
#
# ( 430 / 700 ) NWY
# NWY data already exists, skipping...
#
# ( 431 / 700 ) NXTM
# NXTM data already exists, skipping...
#
# ( 432 / 700 ) NYLD
# NYLD data already exists, skipping...
#
# ( 433 / 700 ) OAK
# OAK data already exists, skipping...
#
# ( 434 / 700 ) OAS
# OAS data already exists, skipping...
#
# ( 435 / 700 ) OBLN
# OBLN data already exists, skipping...
#
# ( 436 / 700 ) OC
# OC data already exists, skipping...
#
# ( 437 / 700 ) OCUL
# OCUL data already exists, skipping...
#
# ( 438 / 700 ) OFSI
# OFSI data already exists, skipping...
#
# ( 439 / 700 ) OIS
# OIS data already exists, skipping...
#
# ( 440 / 700 ) OKTA
# OKTA data already exists, skipping...
#
# ( 441 / 700 ) OLLI
# OLLI data already exists, skipping...
#
# ( 442 / 700 ) OMED
# OMED data already exists, skipping...
#
# ( 443 / 700 ) OMER
# OMER data already exists, skipping...
#
# ( 444 / 700 ) OMPI
# OMPI data already exists, skipping...
#
# ( 445 / 700 ) ONCE
# ONCE data already exists, skipping...
#
# ( 446 / 700 ) ONDK
# ONDK data already exists, skipping...
#
# ( 447 / 700 ) ONE
# ( 448 / 700 ) ONTX
# ONTX data already exists, skipping...
#
# ( 449 / 700 ) OPESU
# OPESU data already exists, skipping...
#
# ( 450 / 700 ) OPGN
# OPGN data already exists, skipping...
#
# ( 451 / 700 ) OPHT
# OPHT data already exists, skipping...
#
# ( 452 / 700 ) OPTN
# OPTN data already exists, skipping...
#
# ( 453 / 700 ) OPTR
# OPTR data already exists, skipping...
#
# ( 454 / 700 ) OPTT
# OPTT data already exists, skipping...
#
# ( 455 / 700 ) ORC
# ORC data already exists, skipping...
#
# ( 456 / 700 ) ORIT
# ORIT data already exists, skipping...
#
# ( 457 / 700 ) OSTK
# OSTK data already exists, skipping...
#
# ( 458 / 700 ) OTIC
# OTIC data already exists, skipping...
#
# ( 459 / 700 ) OTT
# OTT data already exists, skipping...
#
# ( 460 / 700 ) OUNZ
# OUNZ data already exists, skipping...
#
# ( 461 / 700 ) OVID
# OVID data already exists, skipping...
#
# ( 462 / 700 ) OXFD
# OXFD data already exists, skipping...
#
# ( 463 / 700 ) OZM
# OZM data already exists, skipping...
#
# ( 464 / 700 ) P
# P data already exists, skipping...
#
# ( 465 / 700 ) PACB
# PACB data already exists, skipping...
#
# ( 466 / 700 ) PAGP
# PAGP data already exists, skipping...
#
# ( 467 / 700 ) PAHC
# PAHC data already exists, skipping...
#
# ( 468 / 700 ) PANW
# PANW data already exists, skipping...
#
# ( 469 / 700 ) PAY
# PAY data already exists, skipping...
#
# ( 470 / 700 ) PAYC
# PAYC data already exists, skipping...
#
# ( 471 / 700 ) PBF
# PBF data already exists, skipping...
#
# ( 472 / 700 ) PBFX
# PBFX data already exists, skipping...
#
# ( 473 / 700 ) PBIB
# PBIB data already exists, skipping...
#
# ( 474 / 700 ) PBIP
# PBIP data already exists, skipping...
#
# ( 475 / 700 ) PBPB
# PBPB data already exists, skipping...
#
# ( 476 / 700 ) PCRX
# PCRX data already exists, skipping...
#
# ( 477 / 700 ) PCTY
# PCTY data already exists, skipping...
#
# ( 478 / 700 ) PDM
# PDM data already exists, skipping...
#
# ( 479 / 700 ) PE
# PE data already exists, skipping...
#
# ( 480 / 700 ) PEB
# PEB data already exists, skipping...
#
# ( 481 / 700 ) PEGI
# PEGI data already exists, skipping...
#
# ( 482 / 700 ) PER
# PER data already exists, skipping...
#
# ( 483 / 700 ) PETX
# PETX data already exists, skipping...
#
# ( 484 / 700 ) PF
# PF data already exists, skipping...
#
# ( 485 / 700 ) PFMT
# PFMT data already exists, skipping...
#
# ( 486 / 700 ) PFNX
# PFNX data already exists, skipping...
#
# ( 487 / 700 ) PFPT
# PFPT data already exists, skipping...
#
# ( 488 / 700 ) PFS
# PFS data already exists, skipping...
#
# ( 489 / 700 ) PFSI
# PFSI data already exists, skipping...
#
# ( 490 / 700 ) PGTI
# PGTI data already exists, skipping...
#
# ( 491 / 700 ) PIH
# PIH data already exists, skipping...
#
# ( 492 / 700 ) PINC
# PINC data already exists, skipping...
#
# ( 493 / 700 ) PLNT
# PLNT data already exists, skipping...
#
# ( 494 / 700 ) PLSE
# PLSE data already exists, skipping...
#
# ( 495 / 700 ) PMT
# PMT data already exists, skipping...
#
# ( 496 / 700 ) PODD
# PODD data already exists, skipping...
#
# ( 497 / 700 ) POLA
# POLA data already exists, skipping...
#
# ( 498 / 700 ) PRAH
# PRAH data already exists, skipping...
#
# ( 499 / 700 ) PRI
# PRI data already exists, skipping...
#
# ( 500 / 700 ) PRLB
# PRLB data already exists, skipping...
#
# ( 501 / 700 ) PRMW
# PRMW data already exists, skipping...
#
# ( 502 / 700 ) PRSS
# PRSS data already exists, skipping...
#
# ( 503 / 700 ) PRTO
# PRTO data already exists, skipping...
#
# ( 504 / 700 ) PSDO
# PSDO data already exists, skipping...
#
# ( 505 / 700 ) PSXP
# PSXP data already exists, skipping...
#
# ( 506 / 700 ) PTCT
# PTCT data already exists, skipping...
#
# ( 507 / 700 ) PTGX
# PTGX data already exists, skipping...
#
# ( 508 / 700 ) PTLA
# PTLA data already exists, skipping...
#
# ( 509 / 700 ) PUMP
# PUMP data already exists, skipping...
#
# ( 510 / 700 ) PZN
# PZN data already exists, skipping...
#
# ( 511 / 700 ) QES
# QES data already exists, skipping...
#
# ( 512 / 700 ) QLYS
# QLYS data already exists, skipping...
#
# ( 513 / 700 ) QTNA
# QTNA data already exists, skipping...
#
# ( 514 / 700 ) QTRX
# QTRX data already exists, skipping...
#
# ( 515 / 700 ) QTS
# QTS data already exists, skipping...
#
# ( 516 / 700 ) QTWO
# QTWO data already exists, skipping...
#
# ( 517 / 700 ) RAIL
# RAIL data already exists, skipping...
#
# ( 518 / 700 ) RARE
# RARE data already exists, skipping...
#
# ( 519 / 700 ) RCON
# RCON data already exists, skipping...
#
# ( 520 / 700 ) RCUS
# RCUS data already exists, skipping...
#
# ( 521 / 700 ) RDUS
# RDUS data already exists, skipping...
#
# ( 522 / 700 ) REPH
# REPH data already exists, skipping...
#
# ( 523 / 700 ) RESN
# RESN data already exists, skipping...
#
# ( 524 / 700 ) RETA
# RETA data already exists, skipping...
#
# ( 525 / 700 ) REVG
# REVG data already exists, skipping...
#
# ( 526 / 700 ) REXR
# REXR data already exists, skipping...
#
# ( 527 / 700 ) REXX
# REXX data already exists, skipping...
#
# ( 528 / 700 ) RGNX
# RGNX data already exists, skipping...
#
# ( 529 / 700 ) RKDA
# RKDA data already exists, skipping...
#
# ( 530 / 700 ) RLGY
# RLGY data already exists, skipping...
#
# ( 531 / 700 ) RLJ
# RLJ data already exists, skipping...
#
# ( 532 / 700 ) RM
# RM data already exists, skipping...
#
# ( 533 / 700 ) RMAX
# RMAX data already exists, skipping...
#
# ( 534 / 700 ) RNET
# RNET data already exists, skipping...
#
# ( 535 / 700 ) RNG
# RNG data already exists, skipping...
#
# ( 536 / 700 ) ROLL
# ROLL data already exists, skipping...
#
# ( 537 / 700 ) ROMA
# ROMA data already exists, skipping...
#
# ( 538 / 700 ) RUBI
# RUBI data already exists, skipping...
#
# ( 539 / 700 ) RUE
# RUE data already exists, skipping...
#
# ( 540 / 700 ) RUTH
# RUTH data already exists, skipping...
#
# ( 541 / 700 ) RVNC
# RVNC data already exists, skipping...
#
# ( 542 / 700 ) RYTM
# RYTM data already exists, skipping...
#
# ( 543 / 700 ) SABR
# SABR data already exists, skipping...
#
# ( 544 / 700 ) SACH
# SACH data already exists, skipping...
#
# ( 545 / 700 ) SAMG
# SAMG data already exists, skipping...
#
# ( 546 / 700 ) SAVE
# SAVE data already exists, skipping...
#
# ( 547 / 700 ) SBPH
# SBPH data already exists, skipping...
#
# ( 548 / 700 ) SC
# SC data already exists, skipping...
#
# ( 549 / 700 ) SDEV
# SDEV data already exists, skipping...
#
# ( 550 / 700 ) SDPI
# SDPI data already exists, skipping...
#
# ( 551 / 700 ) SDR
# SDR data already exists, skipping...
#
# ( 552 / 700 ) SDT
# SDT data already exists, skipping...
#
# ( 553 / 700 ) SEAS
# SEAS data already exists, skipping...
#
# ( 554 / 700 ) SGOL
# SGOL data already exists, skipping...
#
# ( 555 / 700 ) SHAK
# SHAK data already exists, skipping...
#
# ( 556 / 700 ) SHLX
# SHLX data already exists, skipping...
#
# ( 557 / 700 ) SINO
# SINO data already exists, skipping...
#
# ( 558 / 700 ) SITE
# SITE data already exists, skipping...
#
# ( 559 / 700 ) SKIS
# SKIS data already exists, skipping...
#
# ( 560 / 700 ) SLCA
# SLCA data already exists, skipping...
#
# ( 561 / 700 ) SLDB
# SLDB data already exists, skipping...
#
# ( 562 / 700 ) SMCI
# SMCI data already exists, skipping...
#
# ( 563 / 700 ) SMLR
# SMLR data already exists, skipping...
#
# ( 564 / 700 ) SMTX
# SMTX data already exists, skipping...
#
# ( 565 / 700 ) SNCR
# SNCR data already exists, skipping...
#
# ( 566 / 700 ) SNES
# SNES data already exists, skipping...
#
# ( 567 / 700 ) SNMX
# SNMX data already exists, skipping...
#
# ( 568 / 700 ) SNNA
# SNNA data already exists, skipping...
#
# ( 569 / 700 ) SNSS
# SNSS data already exists, skipping...
#
# ( 570 / 700 ) SNX
# SNX data already exists, skipping...
#
# ( 571 / 700 ) SOI
# SOI data already exists, skipping...
#
# ( 572 / 700 ) SOMX
# SOMX data already exists, skipping...
#
# ( 573 / 700 ) SONA
# SONA data already exists, skipping...
#
# ( 574 / 700 ) SOYB
# SOYB data already exists, skipping...
#
# ( 575 / 700 ) SPKE
# SPKE data already exists, skipping...
#
# ( 576 / 700 ) SPLK
# SPLK data already exists, skipping...
#
# ( 577 / 700 ) SPRO
# SPRO data already exists, skipping...
#
# ( 578 / 700 ) SPSC
# SPSC data already exists, skipping...
#
# ( 579 / 700 ) SPWH
# SPWH data already exists, skipping...
#
# ( 580 / 700 ) SPWR
# SPWR data already exists, skipping...
#
# ( 581 / 700 ) SREV
# SREV data already exists, skipping...
#
# ( 582 / 700 ) SRLP
# SRLP data already exists, skipping...
#
# ( 583 / 700 ) SSNC
# SSNC data already exists, skipping...
#
# ( 584 / 700 ) SSTI
# SSTI data already exists, skipping...
#
# ( 585 / 700 ) SSTK
# SSTK data already exists, skipping...
#
# ( 586 / 700 ) STAY
# STAY data already exists, skipping...
#
# ( 587 / 700 ) STDY
# STDY data already exists, skipping...
#
# ( 588 / 700 ) STML
# STML data already exists, skipping...
#
# ( 589 / 700 ) STND
# STND data already exists, skipping...
#
# ( 590 / 700 ) STON
# STON data already exists, skipping...
#
# ( 591 / 700 ) STWD
# STWD data already exists, skipping...
#
# ( 592 / 700 ) SUPN
# SUPN data already exists, skipping...
#
# ( 593 / 700 ) SXC
# SXC data already exists, skipping...
#
# ( 594 / 700 ) SXCP
# SXCP data already exists, skipping...
#
# ( 595 / 700 ) SYF
# SYF data already exists, skipping...
#
# ( 596 / 700 ) SYNA
# SYNA data already exists, skipping...
#
# ( 597 / 700 ) SYRS
# SYRS data already exists, skipping...
#
# ( 598 / 700 ) TAGS
# TAGS data already exists, skipping...
#
# ( 599 / 700 ) TAST
# TAST data already exists, skipping...
#
# ( 600 / 700 ) TBK
# TBK data already exists, skipping...
#
# ( 601 / 700 ) TBNK
# TBNK data already exists, skipping...
#
# ( 602 / 700 ) TCMD
# TCMD data already exists, skipping...
#
# ( 603 / 700 ) TCON
# TCON data already exists, skipping...
#
# ( 604 / 700 ) TCS
# TCS data already exists, skipping...
#
# ( 605 / 700 ) TDG
# TDG data already exists, skipping...
#
# ( 606 / 700 ) TEGP
# TEGP data already exists, skipping...
#
# ( 607 / 700 ) TEP
# TEP data already exists, skipping...
#
# ( 608 / 700 ) TERP
# TERP data already exists, skipping...
#
# ( 609 / 700 ) TFSL
# TFSL data already exists, skipping...
#
# ( 610 / 700 ) TGEN
# TGEN data already exists, skipping...
#
# ( 611 / 700 ) TIS
# TIS data already exists, skipping...
#
# ( 612 / 700 ) TLOG
# TLOG data already exists, skipping...
#
# ( 613 / 700 ) TLP
# TLP data already exists, skipping...
#
# ( 614 / 700 ) TLYS
# TLYS data already exists, skipping...
#
# ( 615 / 700 ) TMHC
# TMHC data already exists, skipping...
#
# ( 616 / 700 ) TNAV
# TNAV data already exists, skipping...
#
# ( 617 / 700 ) TNET
# TNET data already exists, skipping...
#
# ( 618 / 700 ) TNTR
# TNTR data already exists, skipping...
#
# ( 619 / 700 ) TOCA
# TOCA data already exists, skipping...
#
# ( 620 / 700 ) TONS
# TONS data already exists, skipping...
#
# ( 621 / 700 ) TORC
# TORC data already exists, skipping...
#
# ( 622 / 700 ) TOWR
# TOWR data already exists, skipping...
#
# ( 623 / 700 ) TPB
# TPB data already exists, skipping...
#
# ( 624 / 700 ) TPGI
# TPGI data already exists, skipping...
#
# ( 625 / 700 ) TPH
# TPH data already exists, skipping...
#
# ( 626 / 700 ) TPIC
# TPIC data already exists, skipping...
#
# ( 627 / 700 ) TPX
# TPX data already exists, skipping...
#
# ( 628 / 700 ) TRGP
# TRGP data already exists, skipping...
#
# ( 629 / 700 ) TRHC
# TRHC data already exists, skipping...
#
# ( 630 / 700 ) TRMT
# TRMT data already exists, skipping...
#
# ( 631 / 700 ) TTOO
# TTOO data already exists, skipping...
#
# ( 632 / 700 ) TTPH
# TTPH data already exists, skipping...
#
# ( 633 / 700 ) TUSK
# TUSK data already exists, skipping...
#
# ( 634 / 700 ) TVPT
# TVPT data already exists, skipping...
#
# ( 635 / 700 ) TWOU
# TWOU data already exists, skipping...
#
# ( 636 / 700 ) TWTR
# TWTR data already exists, skipping...
#
# ( 637 / 700 ) TXRH
# TXRH data already exists, skipping...
#
# ( 638 / 700 ) TYHT
# TYHT data already exists, skipping...
#
# ( 639 / 700 ) UMRX
# ( 640 / 700 ) UNG
# UNG data already exists, skipping...
#
# ( 641 / 700 ) UPLD
# UPLD data already exists, skipping...
#
# ( 642 / 700 ) USAC
# USAC data already exists, skipping...
#
# ( 643 / 700 ) USCI
# USCI data already exists, skipping...
#
# ( 644 / 700 ) USFD
# USFD data already exists, skipping...
#
# ( 645 / 700 ) VCRA
# VCRA data already exists, skipping...
#
# ( 646 / 700 ) VCTR
# VCTR data already exists, skipping...
#
# ( 647 / 700 ) VCYT
# VCYT data already exists, skipping...
#
# ( 648 / 700 ) VEEV
# VEEV data already exists, skipping...
#
# ( 649 / 700 ) VERI
# VERI data already exists, skipping...
#
# ( 650 / 700 ) VIRT
# VIRT data already exists, skipping...
#
# ( 651 / 700 ) VLP
# VLP data already exists, skipping...
#
# ( 652 / 700 ) VLTR
# VLTR data already exists, skipping...
#
# ( 653 / 700 ) VNCE
# VNCE data already exists, skipping...
#
# ( 654 / 700 ) VNDA
# VNDA data already exists, skipping...
#
# ( 655 / 700 ) VNOM
# VNOM data already exists, skipping...
#
# ( 656 / 700 ) VRA
# VRA data already exists, skipping...
#
# ( 657 / 700 ) VRNS
# VRNS data already exists, skipping...
#
# ( 658 / 700 ) VRNT
# VRNT data already exists, skipping...
#
# ( 659 / 700 ) VRSK
# VRSK data already exists, skipping...
#
# ( 660 / 700 ) VRTU
# VRTU data already exists, skipping...
#
# ( 661 / 700 ) VSAR
# VSAR data already exists, skipping...
#
# ( 662 / 700 ) VSI
# VSI data already exists, skipping...
#
# ( 663 / 700 ) VSLR
# VSLR data already exists, skipping...
#
# ( 664 / 700 ) VSTM
# VSTM data already exists, skipping...
#
# ( 665 / 700 ) VTL
# VTL data already exists, skipping...
#
# ( 666 / 700 ) VTVT
# VTVT data already exists, skipping...
#
# ( 667 / 700 ) VYGR
# VYGR data already exists, skipping...
#
# ( 668 / 700 ) W
# W data already exists, skipping...
#
# ( 669 / 700 ) WAAS
# WAAS data already exists, skipping...
#
# ( 670 / 700 ) WATT
# WATT data already exists, skipping...
#
# ( 671 / 700 ) WCG
# WCG data already exists, skipping...
#
# ( 672 / 700 ) WD
# WD data already exists, skipping...
#
# ( 673 / 700 ) WDAY
# WDAY data already exists, skipping...
#
# ( 674 / 700 ) WEAT
# WEAT data already exists, skipping...
#
# ( 675 / 700 ) WES
# WES data already exists, skipping...
#
# ( 676 / 700 ) WHD
# WHD data already exists, skipping...
#
# ( 677 / 700 ) WHLR
# WHLR data already exists, skipping...
#
# ( 678 / 700 ) WIFI
# WIFI data already exists, skipping...
#
# ( 679 / 700 ) WING
# WING data already exists, skipping...
#
# ( 680 / 700 ) WITE
# WITE data already exists, skipping...
#
# ( 681 / 700 ) WK
# WK data already exists, skipping...
#
# ( 682 / 700 ) WLDN
# WLDN data already exists, skipping...
#
# ( 683 / 700 ) WLKP
# WLKP data already exists, skipping...
#
# ( 684 / 700 ) WLL
# WLL data already exists, skipping...
#
# ( 685 / 700 ) WOW
# WOW data already exists, skipping...
#
# ( 686 / 700 ) WPZ
# WPZ data already exists, skipping...
#
# ( 687 / 700 ) WRD
# WRD data already exists, skipping...
#
# ( 688 / 700 ) WTI
# WTI data already exists, skipping...
#
# ( 689 / 700 ) WTW
# WTW data already exists, skipping...
#
# ( 690 / 700 ) WU
# WU data already exists, skipping...
#
# ( 691 / 700 ) YEXT
# YEXT data already exists, skipping...
#
# ( 692 / 700 ) ZIP
# ZIP data already exists, skipping...
#
# ( 693 / 700 ) ZNGA
# ZNGA data already exists, skipping...
#
# ( 694 / 700 ) ZS
# ZS data already exists, skipping...
#
# ( 695 / 700 ) ZSAN
# ZSAN data already exists, skipping...
#
# ( 696 / 700 ) ZSTN
# ZSTN data already exists, skipping...
#
# ( 697 / 700 ) ZTS
# ZTS data already exists, skipping...
#
# ( 698 / 700 ) ZUMZ
# ZUMZ data already exists, skipping...
#
# ( 699 / 700 ) ZYNE
# ZYNE data already exists, skipping...
#
# ( 700 / 700 ) ZZ
# ZZ data already exists, skipping...
